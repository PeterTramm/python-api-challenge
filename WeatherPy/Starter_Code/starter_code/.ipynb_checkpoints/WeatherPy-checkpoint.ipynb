# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
from scipy.stats import linregress


# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
weather_api_key
# Out:
# 'b0a45ae433134b95fe576791fc1d2bf3'

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 608

# %%
city
# Out:
# 'chiredzi'

# %%
url = "https://api.openweathermap.org/data/2.5/weather?"

city_url = url + "q=" + city + "&appid=" + weather_api_key

city_url

city_weather = requests.get(city_url).json()
print(city_weather.keys())
# Out:
# dict_keys(['coord', 'weather', 'base', 'main', 'visibility', 'wind', 'clouds', 'dt', 'sys', 'timezone', 'id', 'name', 'cod'])

# %%
city_weather['dt']
# Out:
# 1696901950

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "q=" + city + "&appid=" + weather_api_key
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lon']
        city_lng = city_weather['coord']['lat']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bilibino
# Processing Record 2 of Set 1 | grytviken
# Processing Record 3 of Set 1 | abu jibeha
# Processing Record 4 of Set 1 | olonkinbyen
# Processing Record 5 of Set 1 | vilyuchinsk
# Processing Record 6 of Set 1 | lyubinskiy
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | qaqortoq
# Processing Record 11 of Set 1 | adamstown
# Processing Record 12 of Set 1 | newnham
# Processing Record 13 of Set 1 | tay ninh
# Processing Record 14 of Set 1 | hirtshals
# Processing Record 15 of Set 1 | blackmans bay
# Processing Record 16 of Set 1 | port lincoln
# Processing Record 17 of Set 1 | hassi messaoud
# Processing Record 18 of Set 1 | lionel town
# Processing Record 19 of Set 1 | santa ines
# Processing Record 20 of Set 1 | ribeira grande
# Processing Record 21 of Set 1 | ilulissat
# Processing Record 22 of Set 1 | quellon
# Processing Record 23 of Set 1 | whitehorse
# Processing Record 24 of Set 1 | ust-nera
# Processing Record 25 of Set 1 | arias
# Processing Record 26 of Set 1 | port-aux-francais
# Processing Record 27 of Set 1 | east london
# Processing Record 28 of Set 1 | edinburgh of the seven seas
# Processing Record 29 of Set 1 | stanley
# Processing Record 30 of Set 1 | college
# Processing Record 31 of Set 1 | waitangi
# Processing Record 32 of Set 1 | murray bridge
# Processing Record 33 of Set 1 | invercargill
# Processing Record 34 of Set 1 | kristiansund
# Processing Record 35 of Set 1 | butajira
# Processing Record 36 of Set 1 | puerto baquerizo moreno
# Processing Record 37 of Set 1 | la passe
# Processing Record 38 of Set 1 | nogliki
# Processing Record 39 of Set 1 | longyearbyen
# Processing Record 40 of Set 1 | banda aceh
# Processing Record 41 of Set 1 | west island
# Processing Record 42 of Set 1 | vila franca do campo
# Processing Record 43 of Set 1 | talnakh
# Processing Record 44 of Set 1 | severo-yeniseyskiy
# Processing Record 45 of Set 1 | howrah
# Processing Record 46 of Set 1 | punta arenas
# Processing Record 47 of Set 1 | tangail
# Processing Record 48 of Set 1 | umm kaddadah
# Processing Record 49 of Set 1 | afaahiti
# Processing Record 50 of Set 1 | vohipaho
# City not found. Skipping...
# Processing Record 0 of Set 2 | bethel
# Processing Record 1 of Set 2 | isafjordur
# Processing Record 2 of Set 2 | kerbakhiar
# Processing Record 3 of Set 2 | ambalangoda
# Processing Record 4 of Set 2 | bredasdorp
# Processing Record 5 of Set 2 | nagqu
# Processing Record 6 of Set 2 | kentville
# Processing Record 7 of Set 2 | yemva
# Processing Record 8 of Set 2 | kirensk
# Processing Record 9 of Set 2 | tsiombe
# Processing Record 10 of Set 2 | papatowai
# Processing Record 11 of Set 2 | utrik
# Processing Record 12 of Set 2 | iskateley
# Processing Record 13 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 14 of Set 2 | fortuna
# Processing Record 15 of Set 2 | hawaiian paradise park
# Processing Record 16 of Set 2 | east ballina
# Processing Record 17 of Set 2 | abingdon
# Processing Record 18 of Set 2 | malvan
# Processing Record 19 of Set 2 | susuman
# Processing Record 20 of Set 2 | minas de marcona
# Processing Record 21 of Set 2 | machico
# Processing Record 22 of Set 2 | charters towers
# Processing Record 23 of Set 2 | bontang
# Processing Record 24 of Set 2 | geraldton
# Processing Record 25 of Set 2 | mananjary
# Processing Record 26 of Set 2 | codrington
# Processing Record 27 of Set 2 | ta`u
# Processing Record 28 of Set 2 | vadso
# Processing Record 29 of Set 2 | alice springs
# Processing Record 30 of Set 2 | etropole
# Processing Record 31 of Set 2 | chenzhou
# Processing Record 32 of Set 2 | menemen
# Processing Record 33 of Set 2 | illela
# Processing Record 34 of Set 2 | saipan
# Processing Record 35 of Set 2 | nadi
# Processing Record 36 of Set 2 | nemuro
# Processing Record 37 of Set 2 | laizhou
# Processing Record 38 of Set 2 | okhotsk
# Processing Record 39 of Set 2 | luwuk
# Processing Record 40 of Set 2 | alofi
# Processing Record 41 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 42 of Set 2 | nar'yan-mar
# Processing Record 43 of Set 2 | cidreira
# Processing Record 44 of Set 2 | fale old settlement
# Processing Record 45 of Set 2 | san cristobal
# Processing Record 46 of Set 2 | coquimbo
# Processing Record 47 of Set 2 | haiku-pauwela
# Processing Record 48 of Set 2 | coahuayana de hidalgo
# Processing Record 49 of Set 2 | anapolis
# Processing Record 0 of Set 3 | grand falls-windsor
# Processing Record 1 of Set 3 | nova vicosa
# Processing Record 2 of Set 3 | morrope
# Processing Record 3 of Set 3 | polyarnyy
# Processing Record 4 of Set 3 | brokopondo
# Processing Record 5 of Set 3 | puerto natales
# Processing Record 6 of Set 3 | berbera
# Processing Record 7 of Set 3 | dobrich
# Processing Record 8 of Set 3 | pingliang
# Processing Record 9 of Set 3 | yagry
# City not found. Skipping...
# Processing Record 10 of Set 3 | timmins
# Processing Record 11 of Set 3 | ulsteinvik
# Processing Record 12 of Set 3 | iqaluit
# Processing Record 13 of Set 3 | puerto ayora
# Processing Record 14 of Set 3 | margaret river
# Processing Record 15 of Set 3 | aksu
# Processing Record 16 of Set 3 | pisco
# Processing Record 17 of Set 3 | dengzhou
# Processing Record 18 of Set 3 | weno
# Processing Record 19 of Set 3 | kuqa
# Processing Record 20 of Set 3 | nova xavantina
# Processing Record 21 of Set 3 | kodiak
# Processing Record 22 of Set 3 | kudahuvadhoo
# Processing Record 23 of Set 3 | nalerigu
# City not found. Skipping...
# Processing Record 24 of Set 3 | neietsu
# Processing Record 25 of Set 3 | kataragama
# City not found. Skipping...
# Processing Record 26 of Set 3 | la pineda
# Processing Record 27 of Set 3 | tachilek
# City not found. Skipping...
# Processing Record 28 of Set 3 | sitka
# Processing Record 29 of Set 3 | kaohsiung
# Processing Record 30 of Set 3 | terbanggi besar
# Processing Record 31 of Set 3 | bukama
# Processing Record 32 of Set 3 | calbuco
# Processing Record 33 of Set 3 | mount gambier
# Processing Record 34 of Set 3 | port elizabeth
# Processing Record 35 of Set 3 | happy valley-goose bay
# Processing Record 36 of Set 3 | port mathurin
# Processing Record 37 of Set 3 | badger
# Processing Record 38 of Set 3 | lihue
# Processing Record 39 of Set 3 | nevada
# Processing Record 40 of Set 3 | khuzdar
# Processing Record 41 of Set 3 | warrnambool
# Processing Record 42 of Set 3 | yellowknife
# Processing Record 43 of Set 3 | villa gesell
# Processing Record 44 of Set 3 | akrehamn
# Processing Record 45 of Set 3 | arkhangel'sk
# Processing Record 46 of Set 3 | caleta de carquin
# Processing Record 47 of Set 3 | yuto
# Processing Record 48 of Set 3 | malango
# Processing Record 49 of Set 3 | plainview
# Processing Record 0 of Set 4 | san pedro
# Processing Record 1 of Set 4 | boende
# Processing Record 2 of Set 4 | feijo
# Processing Record 3 of Set 4 | ust'-uda
# Processing Record 4 of Set 4 | enewetak
# Processing Record 5 of Set 4 | nova sintra
# Processing Record 6 of Set 4 | cumbum
# Processing Record 7 of Set 4 | luganville
# Processing Record 8 of Set 4 | azhikkal
# Processing Record 9 of Set 4 | dunblane
# Processing Record 10 of Set 4 | nishinoomote
# Processing Record 11 of Set 4 | laguna
# Processing Record 12 of Set 4 | isle of lewis
# City not found. Skipping...
# Processing Record 13 of Set 4 | gurupi
# Processing Record 14 of Set 4 | ujae
# Processing Record 15 of Set 4 | rehoboth
# Processing Record 16 of Set 4 | san juan de miraflores
# Processing Record 17 of Set 4 | guanica
# Processing Record 18 of Set 4 | wailua homesteads
# Processing Record 19 of Set 4 | ojai
# Processing Record 20 of Set 4 | kurgunta
# Processing Record 21 of Set 4 | palmer
# Processing Record 22 of Set 4 | hadibu
# Processing Record 23 of Set 4 | tralee
# Processing Record 24 of Set 4 | egilsstadir
# Processing Record 25 of Set 4 | hoxtolgay
# City not found. Skipping...
# Processing Record 26 of Set 4 | ivdel'
# Processing Record 27 of Set 4 | ankang
# Processing Record 28 of Set 4 | hamilton
# Processing Record 29 of Set 4 | arkalyk
# Processing Record 30 of Set 4 | chifeng
# Processing Record 31 of Set 4 | avarua
# Processing Record 32 of Set 4 | beichengqu
# Processing Record 33 of Set 4 | sur
# Processing Record 34 of Set 4 | kokopo
# Processing Record 35 of Set 4 | queenstown
# Processing Record 36 of Set 4 | oamaru
# Processing Record 37 of Set 4 | chonchi
# Processing Record 38 of Set 4 | kenora
# Processing Record 39 of Set 4 | bekovo
# Processing Record 40 of Set 4 | vorgashor
# Processing Record 41 of Set 4 | moratalla
# Processing Record 42 of Set 4 | durant
# Processing Record 43 of Set 4 | edd
# Processing Record 44 of Set 4 | oshawa
# Processing Record 45 of Set 4 | celestun
# Processing Record 46 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 47 of Set 4 | jamestown
# Processing Record 48 of Set 4 | walvis bay
# Processing Record 49 of Set 4 | lompoc
# Processing Record 0 of Set 5 | santa ana
# Processing Record 1 of Set 5 | ijuw
# City not found. Skipping...
# Processing Record 2 of Set 5 | anadyr
# Processing Record 3 of Set 5 | san patricio
# Processing Record 4 of Set 5 | port saint john's
# Processing Record 5 of Set 5 | remire-montjoly
# Processing Record 6 of Set 5 | shiyan
# Processing Record 7 of Set 5 | alto barinas
# Processing Record 8 of Set 5 | ampanihy
# Processing Record 9 of Set 5 | kingscliff
# Processing Record 10 of Set 5 | callao
# Processing Record 11 of Set 5 | tiksi
# Processing Record 12 of Set 5 | kiama
# Processing Record 13 of Set 5 | richards bay
# Processing Record 14 of Set 5 | cabo san lucas
# Processing Record 15 of Set 5 | amungan
# Processing Record 16 of Set 5 | sa kaeo
# Processing Record 17 of Set 5 | marka
# Processing Record 18 of Set 5 | lake city
# Processing Record 19 of Set 5 | thompson
# Processing Record 20 of Set 5 | harper
# Processing Record 21 of Set 5 | baglung
# Processing Record 22 of Set 5 | vrangel'
# Processing Record 23 of Set 5 | lebu
# Processing Record 24 of Set 5 | el fasher
# Processing Record 25 of Set 5 | katsuren-haebaru
# Processing Record 26 of Set 5 | tazacorte
# Processing Record 27 of Set 5 | minot air force base
# Processing Record 28 of Set 5 | sakaiminato
# Processing Record 29 of Set 5 | klyuchi
# Processing Record 30 of Set 5 | keban
# Processing Record 31 of Set 5 | udachny
# Processing Record 32 of Set 5 | northam
# Processing Record 33 of Set 5 | burnie
# Processing Record 34 of Set 5 | kapuskasing
# Processing Record 35 of Set 5 | maintirano
# Processing Record 36 of Set 5 | ghadamis
# Processing Record 37 of Set 5 | sajir
# Processing Record 38 of Set 5 | aver-o-mar
# Processing Record 39 of Set 5 | aasiaat
# Processing Record 40 of Set 5 | ostersund
# Processing Record 41 of Set 5 | sanctuary point
# Processing Record 42 of Set 5 | kailua-kona
# Processing Record 43 of Set 5 | condoto
# Processing Record 44 of Set 5 | toledo
# Processing Record 45 of Set 5 | flying fish cove
# Processing Record 46 of Set 5 | namdrik
# Processing Record 47 of Set 5 | georgetown
# Processing Record 48 of Set 5 | ashkasham
# Processing Record 49 of Set 5 | borba
# Processing Record 0 of Set 6 | ostroleka
# Processing Record 1 of Set 6 | rabo de peixe
# Processing Record 2 of Set 6 | as sulayyil
# Processing Record 3 of Set 6 | pont rouge
# Processing Record 4 of Set 6 | nikolayevsk-on-amure
# Processing Record 5 of Set 6 | yinchuan
# Processing Record 6 of Set 6 | booue
# Processing Record 7 of Set 6 | powell
# Processing Record 8 of Set 6 | tayshet
# Processing Record 9 of Set 6 | kitimat
# Processing Record 10 of Set 6 | srivardhan
# Processing Record 11 of Set 6 | tagbina
# Processing Record 12 of Set 6 | keflavik
# Processing Record 13 of Set 6 | warwick
# Processing Record 14 of Set 6 | port alfred
# Processing Record 15 of Set 6 | altay
# Processing Record 16 of Set 6 | igbo-ora
# Processing Record 17 of Set 6 | galliano
# Processing Record 18 of Set 6 | vorkuta
# Processing Record 19 of Set 6 | makokou
# Processing Record 20 of Set 6 | broken hill
# Processing Record 21 of Set 6 | karamay
# City not found. Skipping...
# Processing Record 22 of Set 6 | mount pearl
# Processing Record 23 of Set 6 | gadzhiyevo
# Processing Record 24 of Set 6 | tsarevo
# Processing Record 25 of Set 6 | horta
# Processing Record 26 of Set 6 | ancud
# Processing Record 27 of Set 6 | cable beach
# City not found. Skipping...
# Processing Record 28 of Set 6 | kamiiso
# Processing Record 29 of Set 6 | kirakira
# Processing Record 30 of Set 6 | mercedes
# Processing Record 31 of Set 6 | kisangani
# Processing Record 32 of Set 6 | suva
# Processing Record 33 of Set 6 | devinuwara
# City not found. Skipping...
# Processing Record 34 of Set 6 | kingston
# Processing Record 35 of Set 6 | waupaca
# Processing Record 36 of Set 6 | tromso
# Processing Record 37 of Set 6 | emerald
# Processing Record 38 of Set 6 | faya-largeau
# Processing Record 39 of Set 6 | darbhanga
# Processing Record 40 of Set 6 | saint-pierre
# Processing Record 41 of Set 6 | saint-francois
# Processing Record 42 of Set 6 | freetown
# Processing Record 43 of Set 6 | bakanas
# Processing Record 44 of Set 6 | sao joao da barra
# Processing Record 45 of Set 6 | champerico
# Processing Record 46 of Set 6 | howard springs
# Processing Record 47 of Set 6 | selfoss
# Processing Record 48 of Set 6 | constantia
# Processing Record 49 of Set 6 | labrador city
# Processing Record 0 of Set 7 | rio branco
# Processing Record 1 of Set 7 | shanhaiguan
# Processing Record 2 of Set 7 | poxoreo
# Processing Record 3 of Set 7 | tateyama
# Processing Record 4 of Set 7 | flin flon
# Processing Record 5 of Set 7 | loango
# Processing Record 6 of Set 7 | the pas
# Processing Record 7 of Set 7 | anar darah
# Processing Record 8 of Set 7 | crane
# Processing Record 9 of Set 7 | jiuquan
# Processing Record 10 of Set 7 | manglaur
# Processing Record 11 of Set 7 | saratamata
# City not found. Skipping...
# Processing Record 12 of Set 7 | uturoa
# Processing Record 13 of Set 7 | christchurch
# Processing Record 14 of Set 7 | rongelap
# Processing Record 15 of Set 7 | dogubayazit
# Processing Record 16 of Set 7 | boguchany
# Processing Record 17 of Set 7 | ilanskiy
# Processing Record 18 of Set 7 | nuuk
# Processing Record 19 of Set 7 | el granada
# Processing Record 20 of Set 7 | mankono
# Processing Record 21 of Set 7 | glodeni
# Processing Record 22 of Set 7 | taoudenni
# Processing Record 23 of Set 7 | uthal
# Processing Record 24 of Set 7 | kapa'a
# Processing Record 25 of Set 7 | kosmach
# Processing Record 26 of Set 7 | shamil'kala
# Processing Record 27 of Set 7 | toga village
# City not found. Skipping...
# Processing Record 28 of Set 7 | katutura
# Processing Record 29 of Set 7 | touros
# Processing Record 30 of Set 7 | idri
# Processing Record 31 of Set 7 | riosucio
# Processing Record 32 of Set 7 | tazovsky
# Processing Record 33 of Set 7 | dalandzadgad
# Processing Record 34 of Set 7 | zacharo
# Processing Record 35 of Set 7 | luderitz
# Processing Record 36 of Set 7 | eenhana
# Processing Record 37 of Set 7 | new norfolk
# Processing Record 38 of Set 7 | ataq
# Processing Record 39 of Set 7 | ebon
# Processing Record 40 of Set 7 | san jose village
# City not found. Skipping...
# Processing Record 41 of Set 7 | al qusayr
# Processing Record 42 of Set 7 | buncrana
# Processing Record 43 of Set 7 | surgana
# Processing Record 44 of Set 7 | san luis de la loma
# Processing Record 45 of Set 7 | necochea
# Processing Record 46 of Set 7 | angaur state
# Processing Record 47 of Set 7 | nouadhibou
# Processing Record 48 of Set 7 | kirkland lake
# Processing Record 49 of Set 7 | isola di capo rizzuto
# Processing Record 0 of Set 8 | mantua
# Processing Record 1 of Set 8 | salekhard
# Processing Record 2 of Set 8 | qashyr
# Processing Record 3 of Set 8 | gowurdak
# Processing Record 4 of Set 8 | midvagur
# Processing Record 5 of Set 8 | pariaman
# Processing Record 6 of Set 8 | saint-philippe
# Processing Record 7 of Set 8 | qacha's nek
# Processing Record 8 of Set 8 | rexburg
# Processing Record 9 of Set 8 | virrat
# Processing Record 10 of Set 8 | chos malal
# Processing Record 11 of Set 8 | fukuecho
# Processing Record 12 of Set 8 | cafayate
# Processing Record 13 of Set 8 | houghton
# Processing Record 14 of Set 8 | conception bay south
# Processing Record 15 of Set 8 | griffith
# Processing Record 16 of Set 8 | lerwick
# Processing Record 17 of Set 8 | st. john's
# Processing Record 18 of Set 8 | cururupu
# Processing Record 19 of Set 8 | chernyshevskiy
# Processing Record 20 of Set 8 | azemmour
# Processing Record 21 of Set 8 | oranjemund
# Processing Record 22 of Set 8 | kupang
# Processing Record 23 of Set 8 | colonia
# Processing Record 24 of Set 8 | bodaybo
# Processing Record 25 of Set 8 | tolanaro
# Processing Record 26 of Set 8 | ambon
# Processing Record 27 of Set 8 | porto seguro
# Processing Record 28 of Set 8 | guane
# Processing Record 29 of Set 8 | namtsy
# Processing Record 30 of Set 8 | tabas
# Processing Record 31 of Set 8 | anna regina
# Processing Record 32 of Set 8 | mosfellsbaer
# Processing Record 33 of Set 8 | komsomolsk-on-amur
# Processing Record 34 of Set 8 | morondava
# Processing Record 35 of Set 8 | kendari
# Processing Record 36 of Set 8 | boa vista
# Processing Record 37 of Set 8 | portland
# Processing Record 38 of Set 8 | bejubang dua
# City not found. Skipping...
# Processing Record 39 of Set 8 | along
# Processing Record 40 of Set 8 | smithers
# Processing Record 41 of Set 8 | sal rei
# Processing Record 42 of Set 8 | swift current
# Processing Record 43 of Set 8 | mahajanga
# Processing Record 44 of Set 8 | galesong
# Processing Record 45 of Set 8 | grand rapids
# Processing Record 46 of Set 8 | borisoglebskiy
# Processing Record 47 of Set 8 | ramadi
# Processing Record 48 of Set 8 | kavaratti
# Processing Record 49 of Set 8 | barah
# Processing Record 0 of Set 9 | paranhos
# Processing Record 1 of Set 9 | novyy urgal
# Processing Record 2 of Set 9 | padangsidempuan
# Processing Record 3 of Set 9 | cheremushki
# Processing Record 4 of Set 9 | bull savanna
# Processing Record 5 of Set 9 | cova figueira
# Processing Record 6 of Set 9 | majene
# Processing Record 7 of Set 9 | meulaboh
# Processing Record 8 of Set 9 | miranda
# Processing Record 9 of Set 9 | cacador
# Processing Record 10 of Set 9 | carutapera
# Processing Record 11 of Set 9 | fendou
# Processing Record 12 of Set 9 | buturlinovka
# Processing Record 13 of Set 9 | morehead city
# Processing Record 14 of Set 9 | enriquillo
# Processing Record 15 of Set 9 | xinyu
# Processing Record 16 of Set 9 | lodwar
# Processing Record 17 of Set 9 | katsuura
# Processing Record 18 of Set 9 | williston
# Processing Record 19 of Set 9 | kerikeri
# Processing Record 20 of Set 9 | tabou
# Processing Record 21 of Set 9 | ghormach
# Processing Record 22 of Set 9 | kharp
# Processing Record 23 of Set 9 | ola
# Processing Record 24 of Set 9 | sumbawa besar
# Processing Record 25 of Set 9 | nanzhang chengguanzhen
# Processing Record 26 of Set 9 | knyaze-volkonskoye
# Processing Record 27 of Set 9 | nantucket
# Processing Record 28 of Set 9 | heroica guaymas
# Processing Record 29 of Set 9 | meadow lake
# Processing Record 30 of Set 9 | marquette
# Processing Record 31 of Set 9 | al hazm
# Processing Record 32 of Set 9 | leninskoye
# Processing Record 33 of Set 9 | darwin
# Processing Record 34 of Set 9 | cascais
# Processing Record 35 of Set 9 | preobrazheniye
# Processing Record 36 of Set 9 | metlili chaamba
# Processing Record 37 of Set 9 | kill devil hills
# Processing Record 38 of Set 9 | neryungri
# Processing Record 39 of Set 9 | al fahahil
# Processing Record 40 of Set 9 | puerto madero
# Processing Record 41 of Set 9 | carmen
# Processing Record 42 of Set 9 | atherton
# Processing Record 43 of Set 9 | sibu
# Processing Record 44 of Set 9 | toliara
# Processing Record 45 of Set 9 | manokwari
# Processing Record 46 of Set 9 | tindouf
# Processing Record 47 of Set 9 | parabel'
# Processing Record 48 of Set 9 | antsiranana
# Processing Record 49 of Set 9 | turek
# Processing Record 0 of Set 10 | vilyuysk
# Processing Record 1 of Set 10 | coruripe
# Processing Record 2 of Set 10 | zapolyarnyy
# Processing Record 3 of Set 10 | shimoda
# Processing Record 4 of Set 10 | sakchu-up
# Processing Record 5 of Set 10 | keita
# Processing Record 6 of Set 10 | klaksvik
# Processing Record 7 of Set 10 | laojunmiao
# Processing Record 8 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 9 of Set 10 | miles city
# Processing Record 10 of Set 10 | timra
# Processing Record 11 of Set 10 | vanimo
# Processing Record 12 of Set 10 | peterhead
# Processing Record 13 of Set 10 | port isabel
# Processing Record 14 of Set 10 | batabano
# Processing Record 15 of Set 10 | santiago
# Processing Record 16 of Set 10 | salalah
# Processing Record 17 of Set 10 | nanchong
# Processing Record 18 of Set 10 | san antonio de pale
# Processing Record 19 of Set 10 | shahr-e babak
# Processing Record 20 of Set 10 | khovd
# Processing Record 21 of Set 10 | papao
# Processing Record 22 of Set 10 | milford haven
# Processing Record 23 of Set 10 | hobyo
# Processing Record 24 of Set 10 | isangel
# Processing Record 25 of Set 10 | whitecourt
# Processing Record 26 of Set 10 | kananga
# Processing Record 27 of Set 10 | gagliano del capo
# Processing Record 28 of Set 10 | dayapar
# City not found. Skipping...
# Processing Record 29 of Set 10 | ushtobe
# Processing Record 30 of Set 10 | hammerfest
# Processing Record 31 of Set 10 | gueltat zemmour
# City not found. Skipping...
# Processing Record 32 of Set 10 | carloforte
# Processing Record 33 of Set 10 | san antonio oeste
# Processing Record 34 of Set 10 | la sarre
# Processing Record 35 of Set 10 | mgandu
# Processing Record 36 of Set 10 | agua dulce
# Processing Record 37 of Set 10 | mejit
# Processing Record 38 of Set 10 | the dalles
# Processing Record 39 of Set 10 | moa
# Processing Record 40 of Set 10 | tongliao
# Processing Record 41 of Set 10 | quelimane
# Processing Record 42 of Set 10 | pinhao
# Processing Record 43 of Set 10 | arar
# Processing Record 44 of Set 10 | mossel bay
# Processing Record 45 of Set 10 | phra phutthabat
# Processing Record 46 of Set 10 | puerto maldonado
# Processing Record 47 of Set 10 | jabal os saraj
# Processing Record 48 of Set 10 | amurzet
# Processing Record 49 of Set 10 | puerto carreno
# Processing Record 0 of Set 11 | olyokminsk
# Processing Record 1 of Set 11 | moshkovo
# Processing Record 2 of Set 11 | tofol
# Processing Record 3 of Set 11 | dauphin
# Processing Record 4 of Set 11 | veraval
# Processing Record 5 of Set 11 | bonthe
# Processing Record 6 of Set 11 | smara
# Processing Record 7 of Set 11 | jayapura
# Processing Record 8 of Set 11 | sao raimundo das mangabeiras
# Processing Record 9 of Set 11 | mirabad
# Processing Record 10 of Set 11 | sao vicente
# Processing Record 11 of Set 11 | tiaret
# Processing Record 12 of Set 11 | palu
# Processing Record 13 of Set 11 | quesada
# Processing Record 14 of Set 11 | vila velha
# Processing Record 15 of Set 11 | mugia
# Processing Record 16 of Set 11 | forbesganj
# Processing Record 17 of Set 11 | znomenka
# Processing Record 18 of Set 11 | nalgonda
# Processing Record 19 of Set 11 | atafu village
# Processing Record 20 of Set 11 | rawlins
# Processing Record 21 of Set 11 | onega
# Processing Record 22 of Set 11 | sarina
# Processing Record 23 of Set 11 | jimma
# Processing Record 24 of Set 11 | baardheere
# Processing Record 25 of Set 11 | madaoua
# Processing Record 26 of Set 11 | kourou
# Processing Record 27 of Set 11 | kaka
# Processing Record 28 of Set 11 | euclid
# Processing Record 29 of Set 11 | vingt cinq
# City not found. Skipping...
# Processing Record 30 of Set 11 | ylitornio
# Processing Record 31 of Set 11 | nsunga
# Processing Record 32 of Set 11 | yuzhno-kurilsk
# Processing Record 33 of Set 11 | cargados carajos
# City not found. Skipping...
# Processing Record 34 of Set 11 | aioun
# Processing Record 35 of Set 11 | igrim
# Processing Record 36 of Set 11 | jawf al maqbabah
# Processing Record 37 of Set 11 | peniche
# Processing Record 38 of Set 11 | aykhal
# Processing Record 39 of Set 11 | bumba
# Processing Record 40 of Set 11 | island harbour
# Processing Record 41 of Set 11 | puerto armuelles
# Processing Record 42 of Set 11 | castillos
# Processing Record 43 of Set 11 | nacala
# Processing Record 44 of Set 11 | anibare
# City not found. Skipping...
# Processing Record 45 of Set 11 | la gi
# Processing Record 46 of Set 11 | shalqar
# Processing Record 47 of Set 11 | westport
# Processing Record 48 of Set 11 | ar rutbah
# Processing Record 49 of Set 11 | sena madureira
# Processing Record 0 of Set 12 | suntar
# Processing Record 1 of Set 12 | belyayevka
# Processing Record 2 of Set 12 | fortaleza
# Processing Record 3 of Set 12 | kone
# Processing Record 4 of Set 12 | ternate
# Processing Record 5 of Set 12 | pimentel
# Processing Record 6 of Set 12 | josenii bargaului
# Processing Record 7 of Set 12 | maicao
# Processing Record 8 of Set 12 | el sauzal de rodriguez
# Processing Record 9 of Set 12 | kijang
# Processing Record 10 of Set 12 | ca mau
# Processing Record 11 of Set 12 | saint-mandrier-sur-mer
# Processing Record 12 of Set 12 | tshela
# Processing Record 13 of Set 12 | tadine
# Processing Record 14 of Set 12 | oral
# Processing Record 15 of Set 12 | reitz
# Processing Record 16 of Set 12 | stari kuty
# Processing Record 17 of Set 12 | kegen
# Processing Record 18 of Set 12 | tura
# Processing Record 19 of Set 12 | saldanha
# Processing Record 20 of Set 12 | giyani
# Processing Record 21 of Set 12 | elmendorf air force base
# City not found. Skipping...
# Processing Record 22 of Set 12 | gardnerville ranchos
# Processing Record 23 of Set 12 | da nang
# Processing Record 24 of Set 12 | yeed
# Processing Record 25 of Set 12 | tucupita
# Processing Record 26 of Set 12 | agadez
# Processing Record 27 of Set 12 | antofagasta
# Processing Record 28 of Set 12 | mwene-ditu
# Processing Record 29 of Set 12 | bayan nur
# City not found. Skipping...
# Processing Record 30 of Set 12 | lamu
# Processing Record 31 of Set 12 | cannonvale
# Processing Record 32 of Set 12 | takhatpur
# Processing Record 33 of Set 12 | samamea
# City not found. Skipping...
# Processing Record 34 of Set 12 | marica
# Processing Record 35 of Set 12 | puerto lempira
# Processing Record 36 of Set 12 | amga
# Processing Record 37 of Set 12 | sinop
# Processing Record 38 of Set 12 | pocao de pedras
# Processing Record 39 of Set 12 | igarka
# Processing Record 40 of Set 12 | sandnessjoen
# Processing Record 41 of Set 12 | kuanda
# Processing Record 42 of Set 12 | gobabis
# Processing Record 43 of Set 12 | nikel
# Processing Record 44 of Set 12 | manaure
# Processing Record 45 of Set 12 | estes park
# Processing Record 46 of Set 12 | taksimo
# Processing Record 47 of Set 12 | argo
# Processing Record 48 of Set 12 | pariang
# City not found. Skipping...
# Processing Record 49 of Set 12 | taro
# Processing Record 0 of Set 13 | abou el hassan
# Processing Record 1 of Set 13 | sierra grande
# Processing Record 2 of Set 13 | borogontsy
# Processing Record 3 of Set 13 | bathsheba
# Processing Record 4 of Set 13 | rio grande
# Processing Record 5 of Set 13 | zaigrayevo
# Processing Record 6 of Set 13 | ormara
# Processing Record 7 of Set 13 | chiredzi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'bilibino',
#   'Lat': 166.4372,
#   'Lng': 68.0546,
#   'Max Temp': 264.79,
#   'Humidity': 93,
#   'Cloudiness': 99,
#   'Wind Speed': 0.57,
#   'Country': 'RU',
#   'Date': 1696901893},
#  {'City': 'grytviken',
#   'Lat': -36.5092,
#   'Lng': -54.2811,
#   'Max Temp': 273.05,
#   'Humidity': 77,
#   'Cloudiness': 26,
#   'Wind Speed': 4.72,
#   'Country': 'GS',
#   'Date': 1696901841},
#  {'City': 'abu jibeha',
#   'Lat': 31.2285,
#   'Lng': 11.4562,
#   'Max Temp': 298.79,
#   'Humidity': 56,
#   'Cloudiness': 100,
#   'Wind Speed': 2.31,
#   'Country': 'SD',
#   'Date': 1696901952},
#  {'City': 'olonkinbyen',
#   'Lat': -8.7187,
#   'Lng': 70.9221,
#   'Max Temp': 275.14,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 6.84,
#   'Country': 'SJ',
#   'Date': 1696901944},
#  {'City': 'vilyuchinsk',
#   'Lat': 158.4028,
#   'Lng': 52.9306,
#   'Max Temp': 282.3,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 2.05,
#   'Country': 'RU',
#   'Date': 1696901937},
#  {'City': 'lyubinskiy',
#   'Lat': 72.6925,
#   'Lng': 55.1542,
#   'Max Temp': 287,
#   'Humidity': 47,
#   'Cloudiness': 97,
#   'Wind Speed': 8.34,
#   'Country': 'RU',
#   'Date': 1696901954},
#  {'City': 'ushuaia',
#   'Lat': -68.3,
#   'Lng': -54.8,
#   'Max Temp': 272.96,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 12.86,
#   'Country': 'AR',
#   'Date': 1696901859},
#  {'City': 'albany',
#   'Lat': -73.9662,
#   'Lng': 42.6001,
#   'Max Temp': 282.85,
#   'Humidity': 74,
#   'Cloudiness': 48,
#   'Wind Speed': 2.06,
#   'Country': 'US',
#   'Date': 1696901871},
#  {'City': 'hermanus',
#   'Lat': 19.2345,
#   'Lng': -34.4187,
#   'Max Temp': 287.72,
#   'Humidity': 79,
#   'Cloudiness': 74,
#   'Wind Speed': 9.19,
#   'Country': 'ZA',
#   'Date': 1696901847},
#  {'City': 'qaqortoq',
#   'Lat': -46.0333,
#   'Lng': 60.7167,
#   'Max Temp': 276.84,
#   'Humidity': 64,
#   'Cloudiness': 94,
#   'Wind Speed': 3.3,
#   'Country': 'GL',
#   'Date': 1696901867},
#  {'City': 'adamstown',
#   'Lat': -130.1015,
#   'Lng': -25.066,
#   'Max Temp': 292.95,
#   'Humidity': 65,
#   'Cloudiness': 10,
#   'Wind Speed': 4.81,
#   'Country': 'PN',
#   'Date': 1696901822},
#  {'City': 'newnham',
#   'Lat': 147.1333,
#   'Lng': -41.3833,
#   'Max Temp': 289.63,
#   'Humidity': 51,
#   'Cloudiness': 40,
#   'Wind Speed': 3.09,
#   'Country': 'AU',
#   'Date': 1696901958},
#  {'City': 'tay ninh',
#   'Lat': 106.1,
#   'Lng': 11.3,
#   'Max Temp': 298.57,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 0.99,
#   'Country': 'VN',
#   'Date': 1696901709},
#  {'City': 'hirtshals',
#   'Lat': 9.9592,
#   'Lng': 57.5881,
#   'Max Temp': 284.79,
#   'Humidity': 62,
#   'Cloudiness': 48,
#   'Wind Speed': 7.47,
#   'Country': 'DK',
#   'Date': 1696901959},
#  {'City': 'blackmans bay',
#   'Lat': 147.3167,
#   'Lng': -43.0167,
#   'Max Temp': 289.55,
#   'Humidity': 65,
#   'Cloudiness': 54,
#   'Wind Speed': 2.21,
#   'Country': 'AU',
#   'Date': 1696901820},
#  {'City': 'port lincoln',
#   'Lat': 135.8667,
#   'Lng': -34.7333,
#   'Max Temp': 291.25,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 2.35,
#   'Country': 'AU',
#   'Date': 1696901708},
#  {'City': 'hassi messaoud',
#   'Lat': 6.0729,
#   'Lng': 31.6804,
#   'Max Temp': 295.07,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 2.06,
#   'Country': 'DZ',
#   'Date': 1696901961},
#  {'City': 'lionel town',
#   'Lat': -77.2406,
#   'Lng': 17.8101,
#   'Max Temp': 300.09,
#   'Humidity': 85,
#   'Cloudiness': 80,
#   'Wind Speed': 2.35,
#   'Country': 'JM',
#   'Date': 1696901962},
#  {'City': 'santa ines',
#   'Lat': -45.38,
#   'Lng': -3.6667,
#   'Max Temp': 298.84,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 2.84,
#   'Country': 'BR',
#   'Date': 1696901962},
#  {'City': 'ribeira grande',
#   'Lat': -28.7,
#   'Lng': 38.5167,
#   'Max Temp': 294.69,
#   'Humidity': 88,
#   'Cloudiness': 25,
#   'Wind Speed': 8.49,
#   'Country': 'PT',
#   'Date': 1696901818},
#  {'City': 'ilulissat',
#   'Lat': -51.1,
#   'Lng': 69.2167,
#   'Max Temp': 271.16,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 4.63,
#   'Country': 'GL',
#   'Date': 1696901862},
#  {'City': 'quellon',
#   'Lat': -73.6167,
#   'Lng': -43.1167,
#   'Max Temp': 279.53,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 3.29,
#   'Country': 'CL',
#   'Date': 1696901864},
#  {'City': 'whitehorse',
#   'Lat': -135.0538,
#   'Lng': 60.7161,
#   'Max Temp': 283.58,
#   'Humidity': 90,
#   'Cloudiness': 75,
#   'Wind Speed': 8.23,
#   'Country': 'CA',
#   'Date': 1696901821},
#  {'City': 'ust-nera',
#   'Lat': 143.2,
#   'Lng': 64.5667,
#   'Max Temp': 266.05,
#   'Humidity': 96,
#   'Cloudiness': 89,
#   'Wind Speed': 1.79,
#   'Country': 'RU',
#   'Date': 1696901966},
#  {'City': 'arias',
#   'Lat': -62.4027,
#   'Lng': -33.6441,
#   'Max Temp': 297.16,
#   'Humidity': 24,
#   'Cloudiness': 72,
#   'Wind Speed': 7.88,
#   'Country': 'AR',
#   'Date': 1696901966},
#  {'City': 'port-aux-francais',
#   'Lat': 70.2167,
#   'Lng': -49.35,
#   'Max Temp': 275.22,
#   'Humidity': 76,
#   'Cloudiness': 37,
#   'Wind Speed': 17.41,
#   'Country': 'TF',
#   'Date': 1696901727},
#  {'City': 'east london',
#   'Lat': 27.9116,
#   'Lng': -33.0153,
#   'Max Temp': 288.68,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 3.37,
#   'Country': 'ZA',
#   'Date': 1696901967},
#  {'City': 'edinburgh of the seven seas',
#   'Lat': -12.3116,
#   'Lng': -37.0676,
#   'Max Temp': 286.6,
#   'Humidity': 91,
#   'Cloudiness': 80,
#   'Wind Speed': 0.65,
#   'Country': 'SH',
#   'Date': 1696901855},
#  {'City': 'stanley',
#   'Lat': -1.6985,
#   'Lng': 54.868,
#   'Max Temp': 286.76,
#   'Humidity': 92,
#   'Cloudiness': 20,
#   'Wind Speed': 1.54,
#   'Country': 'GB',
#   'Date': 1696901862},
#  {'City': 'college',
#   'Lat': -147.8028,
#   'Lng': 64.8569,
#   'Max Temp': 273.12,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': 1696901946},
#  {'City': 'waitangi',
#   'Lat': -176.5597,
#   'Lng': -43.9535,
#   'Max Temp': 285.27,
#   'Humidity': 73,
#   'Cloudiness': 16,
#   'Wind Speed': 6.71,
#   'Country': 'NZ',
#   'Date': 1696901842},
#  {'City': 'murray bridge',
#   'Lat': 139.2667,
#   'Lng': -35.1167,
#   'Max Temp': 295.56,
#   'Humidity': 30,
#   'Cloudiness': 8,
#   'Wind Speed': 2.26,
#   'Country': 'AU',
#   'Date': 1696901695},
#  {'City': 'invercargill',
#   'Lat': 168.35,
#   'Lng': -46.4,
#   'Max Temp': 283.16,
#   'Humidity': 63,
#   'Cloudiness': 87,
#   'Wind Speed': 7.15,
#   'Country': 'NZ',
#   'Date': 1696901832},
#  {'City': 'kristiansund',
#   'Lat': 7.732,
#   'Lng': 63.1115,
#   'Max Temp': 283.51,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 4.12,
#   'Country': 'NO',
#   'Date': 1696901972},
#  {'City': 'butajira',
#   'Lat': 38.3667,
#   'Lng': 8.1167,
#   'Max Temp': 287.36,
#   'Humidity': 69,
#   'Cloudiness': 27,
#   'Wind Speed': 2.43,
#   'Country': 'ET',
#   'Date': 1696901973},
#  {'City': 'puerto baquerizo moreno',
#   'Lat': -89.6,
#   'Lng': -0.9,
#   'Max Temp': 297.18,
#   'Humidity': 82,
#   'Cloudiness': 37,
#   'Wind Speed': 5.05,
#   'Country': 'EC',
#   'Date': 1696901902},
#  {'City': 'la passe',
#   'Lat': -0.8967,
#   'Lng': 45.5549,
#   'Max Temp': 286.28,
#   'Humidity': 63,
#   'Cloudiness': 5,
#   'Wind Speed': 1.75,
#   'Country': 'FR',
#   'Date': 1696901974},
#  {'City': 'nogliki',
#   'Lat': 143.1667,
#   'Lng': 51.8333,
#   'Max Temp': 279.45,
#   'Humidity': 85,
#   'Cloudiness': 7,
#   'Wind Speed': 2.68,
#   'Country': 'RU',
#   'Date': 1696901940},
#  {'City': 'longyearbyen',
#   'Lat': 15.6401,
#   'Lng': 78.2186,
#   'Max Temp': 267.06,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 7.2,
#   'Country': 'SJ',
#   'Date': 1696901834},
#  {'City': 'banda aceh',
#   'Lat': 95.3222,
#   'Lng': 5.5577,
#   'Max Temp': 300.65,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 0.74,
#   'Country': 'ID',
#   'Date': 1696901976},
#  {'City': 'west island',
#   'Lat': 96.8225,
#   'Lng': -12.1568,
#   'Max Temp': 300.14,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 7.2,
#   'Country': 'CC',
#   'Date': 1696901858},
#  {'City': 'vila franca do campo',
#   'Lat': -25.4333,
#   'Lng': 37.7167,
#   'Max Temp': 295.38,
#   'Humidity': 90,
#   'Cloudiness': 26,
#   'Wind Speed': 9.3,
#   'Country': 'PT',
#   'Date': 1696901853},
#  {'City': 'talnakh',
#   'Lat': 88.3972,
#   'Lng': 69.4865,
#   'Max Temp': 279.38,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 5.38,
#   'Country': 'RU',
#   'Date': 1696901825},
#  {'City': 'severo-yeniseyskiy',
#   'Lat': 93.0408,
#   'Lng': 60.3725,
#   'Max Temp': 281.25,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 3.58,
#   'Country': 'RU',
#   'Date': 1696901978},
#  {'City': 'howrah',
#   'Lat': 88.3103,
#   'Lng': 22.5892,
#   'Max Temp': 303.15,
#   'Humidity': 84,
#   'Cloudiness': 19,
#   'Wind Speed': 2.06,
#   'Country': 'IN',
#   'Date': 1696901979},
#  {'City': 'punta arenas',
#   'Lat': -70.9167,
#   'Lng': -53.15,
#   'Max Temp': 274.21,
#   'Humidity': 80,
#   'Cloudiness': 20,
#   'Wind Speed': 4.12,
#   'Country': 'CL',
#   'Date': 1696901875},
#  {'City': 'tangail',
#   'Lat': 89.9167,
#   'Lng': 24.25,
#   'Max Temp': 300.47,
#   'Humidity': 78,
#   'Cloudiness': 97,
#   'Wind Speed': 2,
#   'Country': 'BD',
#   'Date': 1696901980},
#  {'City': 'umm kaddadah',
#   'Lat': 26.6876,
#   'Lng': 13.6017,
#   'Max Temp': 305.35,
#   'Humidity': 24,
#   'Cloudiness': 78,
#   'Wind Speed': 4.68,
#   'Country': 'SD',
#   'Date': 1696901981},
#  {'City': 'afaahiti',
#   'Lat': -149.2833,
#   'Lng': -17.75,
#   'Max Temp': 301.08,
#   'Humidity': 75,
#   'Cloudiness': 61,
#   'Wind Speed': 6.38,
#   'Country': 'PF',
#   'Date': 1696901839},
#  {'City': 'bethel',
#   'Lat': -73.414,
#   'Lng': 41.3712,
#   'Max Temp': 285.75,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1696901822},
#  {'City': 'isafjordur',
#   'Lat': -23.124,
#   'Lng': 66.0755,
#   'Max Temp': 274.13,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 14.67,
#   'Country': 'IS',
#   'Date': 1696901867},
#  {'City': 'kerbakhiar',
#   'Lat': 46.0383,
#   'Lng': 40.1067,
#   'Max Temp': 281.36,
#   'Humidity': 88,
#   'Cloudiness': 46,
#   'Wind Speed': 1.39,
#   'Country': 'AZ',
#   'Date': 1696901985},
#  {'City': 'ambalangoda',
#   'Lat': 80.0538,
#   'Lng': 6.2355,
#   'Max Temp': 299.32,
#   'Humidity': 86,
#   'Cloudiness': 81,
#   'Wind Speed': 2.89,
#   'Country': 'LK',
#   'Date': 1696901986},
#  {'City': 'bredasdorp',
#   'Lat': 20.0403,
#   'Lng': -34.5322,
#   'Max Temp': 285.71,
#   'Humidity': 92,
#   'Cloudiness': 48,
#   'Wind Speed': 4.82,
#   'Country': 'ZA',
#   'Date': 1696901870},
#  {'City': 'nagqu',
#   'Lat': 92,
#   'Lng': 31.5,
#   'Max Temp': 277.02,
#   'Humidity': 57,
#   'Cloudiness': 9,
#   'Wind Speed': 3.51,
#   'Country': 'CN',
#   'Date': 1696901935},
#  {'City': 'kentville',
#   'Lat': -64.4988,
#   'Lng': 45.0835,
#   'Max Temp': 287.82,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 1.03,
#   'Country': 'CA',
#   'Date': 1696901988},
#  {'City': 'yemva',
#   'Lat': 50.8594,
#   'Lng': 62.59,
#   'Max Temp': 275.4,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Date': 1696901989},
#  {'City': 'kirensk',
#   'Lat': 108.1119,
#   'Lng': 57.7853,
#   'Max Temp': 280.38,
#   'Humidity': 94,
#   'Cloudiness': 19,
#   'Wind Speed': 1.79,
#   'Country': 'RU',
#   'Date': 1696901990},
#  {'City': 'tsiombe',
#   'Lat': 45.4833,
#   'Lng': -25.3,
#   'Max Temp': 294.67,
#   'Humidity': 85,
#   'Cloudiness': 78,
#   'Wind Speed': 3.61,
#   'Country': 'MG',
#   'Date': 1696901991},
#  {'City': 'papatowai',
#   'Lat': 169.4708,
#   'Lng': -46.5619,
#   'Max Temp': 282.58,
#   'Humidity': 57,
#   'Cloudiness': 85,
#   'Wind Speed': 8.36,
#   'Country': 'NZ',
#   'Date': 1696901872},
#  {'City': 'utrik',
#   'Lat': 169.8474,
#   'Lng': 11.2278,
#   'Max Temp': 301.31,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 5.16,
#   'Country': 'MH',
#   'Date': 1696901992},
#  {'City': 'iskateley',
#   'Lat': 53.1512,
#   'Lng': 67.6803,
#   'Max Temp': 274.27,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 6.26,
#   'Country': 'RU',
#   'Date': 1696901929},
#  {'City': 'fortuna',
#   'Lat': -124.1573,
#   'Lng': 40.5982,
#   'Max Temp': 287.79,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4.12,
#   'Country': 'US',
#   'Date': 1696901994},
#  {'City': 'hawaiian paradise park',
#   'Lat': -154.9731,
#   'Lng': 19.5933,
#   'Max Temp': 301.88,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 4.63,
#   'Country': 'US',
#   'Date': 1696901898},
#  {'City': 'east ballina',
#   'Lat': 153.5833,
#   'Lng': -28.8667,
#   'Max Temp': 296.07,
#   'Humidity': 54,
#   'Cloudiness': 47,
#   'Wind Speed': 5.39,
#   'Country': 'AU',
#   'Date': 1696901995},
#  {'City': 'abingdon',
#   'Lat': -1.2828,
#   'Lng': 51.6711,
#   'Max Temp': 288.4,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Country': 'GB',
#   'Date': 1696901996},
#  {'City': 'malvan',
#   'Lat': 73.4667,
#   'Lng': 16.0667,
#   'Max Temp': 299.04,
#   'Humidity': 88,
#   'Cloudiness': 4,
#   'Wind Speed': 1.59,
#   'Country': 'IN',
#   'Date': 1696901997},
#  {'City': 'susuman',
#   'Lat': 148.1667,
#   'Lng': 62.7833,
#   'Max Temp': 264.81,
#   'Humidity': 87,
#   'Cloudiness': 65,
#   'Wind Speed': 0.89,
#   'Country': 'RU',
#   'Date': 1696901837},
#  {'City': 'minas de marcona',
#   'Lat': -75.1103,
#   'Lng': -15.2119,
#   'Max Temp': 287.69,
#   'Humidity': 81,
#   'Cloudiness': 95,
#   'Wind Speed': 4.66,
#   'Country': 'PE',
#   'Date': 1696901998},
#  {'City': 'machico',
#   'Lat': -16.7667,
#   'Lng': 32.7,
#   'Max Temp': 300.93,
#   'Humidity': 49,
#   'Cloudiness': 20,
#   'Wind Speed': 1.54,
#   'Country': 'PT',
#   'Date': 1696901906},
#  {'City': 'charters towers',
#   'Lat': 146.2667,
#   'Lng': -20.1,
#   'Max Temp': 301.51,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 3.45,
#   'Country': 'AU',
#   'Date': 1696901999},
#  {'City': 'bontang',
#   'Lat': 117.5,
#   'Lng': 0.1333,
#   'Max Temp': 303.28,
#   'Humidity': 64,
#   'Cloudiness': 76,
#   'Wind Speed': 3.86,
#   'Country': 'ID',
#   'Date': 1696902000},
#  {'City': 'geraldton',
#   'Lat': 114.6,
#   'Lng': -28.7667,
#   'Max Temp': 293.38,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 8.23,
#   'Country': 'AU',
#   'Date': 1696901804},
#  {'City': 'mananjary',
#   'Lat': 48.3333,
#   'Lng': -21.2167,
#   'Max Temp': 293.12,
#   'Humidity': 93,
#   'Cloudiness': 21,
#   'Wind Speed': 2.55,
#   'Country': 'MG',
#   'Date': 1696902002},
#  {'City': 'codrington',
#   'Lat': 141.9667,
#   'Lng': -38.2667,
#   'Max Temp': 289.56,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 3.96,
#   'Country': 'AU',
#   'Date': 1696901937},
#  {'City': 'ta`u',
#   'Lat': -169.5144,
#   'Lng': -14.2336,
#   'Max Temp': 300.41,
#   'Humidity': 80,
#   'Cloudiness': 86,
#   'Wind Speed': 5.23,
#   'Country': 'AS',
#   'Date': 1696902003},
#  {'City': 'vadso',
#   'Lat': 29.7487,
#   'Lng': 70.0744,
#   'Max Temp': 271.64,
#   'Humidity': 86,
#   'Cloudiness': 77,
#   'Wind Speed': 6.17,
#   'Country': 'NO',
#   'Date': 1696901921},
#  {'City': 'alice springs',
#   'Lat': 133.8833,
#   'Lng': -23.7,
#   'Max Temp': 299.9,
#   'Humidity': 10,
#   'Cloudiness': 0,
#   'Wind Speed': 5.66,
#   'Country': 'AU',
#   'Date': 1696901915},
#  {'City': 'etropole',
#   'Lat': 24,
#   'Lng': 42.8333,
#   'Max Temp': 284.44,
#   'Humidity': 45,
#   'Cloudiness': 100,
#   'Wind Speed': 0.7,
#   'Country': 'BG',
#   'Date': 1696902005},
#  {'City': 'chenzhou',
#   'Lat': 113.0333,
#   'Lng': 25.8,
#   'Max Temp': 290.58,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 1.46,
#   'Country': 'CN',
#   'Date': 1696902006},
#  {'City': 'menemen',
#   'Lat': 27.0694,
#   'Lng': 38.6075,
#   'Max Temp': 290.8,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 2.57,
#   'Country': 'TR',
#   'Date': 1696901921},
#  {'City': 'illela',
#   'Lat': 5.2975,
#   'Lng': 13.7292,
#   'Max Temp': 303.03,
#   'Humidity': 25,
#   'Cloudiness': 21,
#   'Wind Speed': 3.57,
#   'Country': 'NG',
#   'Date': 1696902007},
#  {'City': 'saipan',
#   'Lat': 145.701,
#   'Lng': 15.1355,
#   'Max Temp': 301.54,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 10.8,
#   'Country': 'MP',
#   'Date': 1696901895},
#  {'City': 'nadi',
#   'Lat': 177.4167,
#   'Lng': -17.8,
#   'Max Temp': 302.15,
#   'Humidity': 48,
#   'Cloudiness': 20,
#   'Wind Speed': 2.57,
#   'Country': 'FJ',
#   'Date': 1696901810},
#  {'City': 'nemuro',
#   'Lat': 145.575,
#   'Lng': 43.3236,
#   'Max Temp': 287.51,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 9.3,
#   'Country': 'JP',
#   'Date': 1696901659},
#  {'City': 'laizhou',
#   'Lat': 119.9214,
#   'Lng': 37.1717,
#   'Max Temp': 293.38,
#   'Humidity': 54,
#   'Cloudiness': 85,
#   'Wind Speed': 5.55,
#   'Country': 'CN',
#   'Date': 1696902010},
#  {'City': 'okhotsk',
#   'Lat': 143.3,
#   'Lng': 59.3833,
#   'Max Temp': 275.44,
#   'Humidity': 91,
#   'Cloudiness': 0,
#   'Wind Speed': 8.97,
#   'Country': 'RU',
#   'Date': 1696902011},
#  {'City': 'luwuk',
#   'Lat': 122.7875,
#   'Lng': -0.9516,
#   'Max Temp': 303.92,
#   'Humidity': 52,
#   'Cloudiness': 61,
#   'Wind Speed': 4.57,
#   'Country': 'ID',
#   'Date': 1696902011},
#  {'City': 'alofi',
#   'Lat': -169.9187,
#   'Lng': -19.0595,
#   'Max Temp': 300.09,
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 6.17,
#   'Country': 'NU',
#   'Date': 1696901931},
#  {'City': "nar'yan-mar",
#   'Lat': 53.087,
#   'Lng': 67.6713,
#   'Max Temp': 274.32,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 6.26,
#   'Country': 'RU',
#   'Date': 1696901885},
#  {'City': 'cidreira',
#   'Lat': -50.2056,
#   'Lng': -30.1811,
#   'Max Temp': 289.86,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 3.84,
#   'Country': 'BR',
#   'Date': 1696902014},
#  {'City': 'fale old settlement',
#   'Lat': -171.2468,
#   'Lng': -9.3852,
#   'Max Temp': 302.01,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 6.44,
#   'Country': 'TK',
#   'Date': 1696901908},
#  {'City': 'san cristobal',
#   'Lat': -72.225,
#   'Lng': 7.7669,
#   'Max Temp': 297.25,
#   'Humidity': 95,
#   'Cloudiness': 87,
#   'Wind Speed': 1.18,
#   'Country': 'VE',
#   'Date': 1696902015},
#  {'City': 'coquimbo',
#   'Lat': -71.3436,
#   'Lng': -29.9533,
#   'Max Temp': 287,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 0.51,
#   'Country': 'CL',
#   'Date': 1696902016},
#  {'City': 'haiku-pauwela',
#   'Lat': -156.3051,
#   'Lng': 20.9219,
#   'Max Temp': 302.16,
#   'Humidity': 60,
#   'Cloudiness': 20,
#   'Wind Speed': 8.75,
#   'Country': 'US',
#   'Date': 1696902017},
#  {'City': 'coahuayana de hidalgo',
#   'Lat': -103.6583,
#   'Lng': 18.7,
#   'Max Temp': 298.36,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 0.46,
#   'Country': 'MX',
#   'Date': 1696902018},
#  {'City': 'anapolis',
#   'Lat': -48.9528,
#   'Lng': -16.3267,
#   'Max Temp': 298.41,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 3.6,
#   'Country': 'BR',
#   'Date': 1696902019},
#  {'City': 'grand falls-windsor',
#   'Lat': -55.6649,
#   'Lng': 48.9332,
#   'Max Temp': 283.99,
#   'Humidity': 92,
#   'Cloudiness': 96,
#   'Wind Speed': 2.14,
#   'Country': 'CA',
#   'Date': 1696901852},
#  {'City': 'nova vicosa',
#   'Lat': -39.3719,
#   'Lng': -17.8919,
#   'Max Temp': 297.6,
#   'Humidity': 84,
#   'Cloudiness': 24,
#   'Wind Speed': 5.91,
#   'Country': 'BR',
#   'Date': 1696902020},
#  {'City': 'morrope',
#   'Lat': -80.0111,
#   'Lng': -6.5417,
#   'Max Temp': 294.21,
#   'Humidity': 82,
#   'Cloudiness': 31,
#   'Wind Speed': 5.77,
#   'Country': 'PE',
#   'Date': 1696902021},
#  {'City': 'polyarnyy',
#   'Lat': 33.4478,
#   'Lng': 69.1989,
#   'Max Temp': 272.83,
#   'Humidity': 82,
#   'Cloudiness': 98,
#   'Wind Speed': 6.11,
#   'Country': 'RU',
#   'Date': 1696902021},
#  {'City': 'brokopondo',
#   'Lat': -55.1667,
#   'Lng': 4.75,
#   'Max Temp': 299.48,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 4.8,
#   'Country': 'SR',
#   'Date': 1696902022},
#  {'City': 'puerto natales',
#   'Lat': -72.4875,
#   'Lng': -51.7236,
#   'Max Temp': 273.87,
#   'Humidity': 77,
#   'Cloudiness': 50,
#   'Wind Speed': 5.72,
#   'Country': 'CL',
#   'Date': 1696901907},
#  {'City': 'berbera',
#   'Lat': 45.0143,
#   'Lng': 10.4396,
#   'Max Temp': 300.63,
#   'Humidity': 78,
#   'Cloudiness': 83,
#   'Wind Speed': 2.7,
#   'Country': 'SO',
#   'Date': 1696902023},
#  {'City': 'dobrich',
#   'Lat': 27.8333,
#   'Lng': 43.5667,
#   'Max Temp': 286.25,
#   'Humidity': 66,
#   'Cloudiness': 66,
#   'Wind Speed': 2.68,
#   'Country': 'BG',
#   'Date': 1696901767},
#  {'City': 'pingliang',
#   'Lat': 106.6861,
#   'Lng': 35.5392,
#   'Max Temp': 286.63,
#   'Humidity': 66,
#   'Cloudiness': 1,
#   'Wind Speed': 2.13,
#   'Country': 'CN',
#   'Date': 1696902025},
#  {'City': 'timmins',
#   'Lat': -81.3331,
#   'Lng': 48.4669,
#   'Max Temp': 275.05,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 2.57,
#   'Country': 'CA',
#   'Date': 1696902026},
#  {'City': 'ulsteinvik',
#   'Lat': 5.8487,
#   'Lng': 62.3432,
#   'Max Temp': 283.88,
#   'Humidity': 75,
#   'Cloudiness': 87,
#   'Wind Speed': 3.58,
#   'Country': 'NO',
#   'Date': 1696902027},
#  {'City': 'iqaluit',
#   'Lat': -68.5145,
#   'Lng': 63.7506,
#   'Max Temp': 272,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 4.12,
#   'Country': 'CA',
#   'Date': 1696901582},
#  {'City': 'puerto ayora',
#   'Lat': -90.3518,
#   'Lng': -0.7393,
#   'Max Temp': 297.34,
#   'Humidity': 94,
#   'Cloudiness': 33,
#   'Wind Speed': 3.13,
#   'Country': 'EC',
#   'Date': 1696901878},
#  {'City': 'margaret river',
#   'Lat': 115.0667,
#   'Lng': -33.95,
#   'Max Temp': 288.21,
#   'Humidity': 52,
#   'Cloudiness': 52,
#   'Wind Speed': 5.57,
#   'Country': 'AU',
#   'Date': 1696901912},
#  {'City': 'aksu',
#   'Lat': 80.2644,
#   'Lng': 41.1231,
#   'Max Temp': 290.27,
#   'Humidity': 43,
#   'Cloudiness': 99,
#   'Wind Speed': 2.71,
#   'Country': 'CN',
#   'Date': 1696901913},
#  {'City': 'pisco',
#   'Lat': -76.2167,
#   'Lng': -13.7,
#   'Max Temp': 291.49,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 6.69,
#   'Country': 'PE',
#   'Date': 1696902030},
#  {'City': 'dengzhou',
#   'Lat': 120.7508,
#   'Lng': 37.8086,
#   'Max Temp': 292.28,
#   'Humidity': 59,
#   'Cloudiness': 59,
#   'Wind Speed': 7.39,
#   'Country': 'CN',
#   'Date': 1696902031},
#  {'City': 'weno',
#   'Lat': 151.8468,
#   'Lng': 7.4515,
#   'Max Temp': 303.12,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 4.12,
#   'Country': 'FM',
#   'Date': 1696902032},
#  {'City': 'kuqa',
#   'Lat': 82.9364,
#   'Lng': 41.7278,
#   'Max Temp': 291.03,
#   'Humidity': 40,
#   'Cloudiness': 99,
#   'Wind Speed': 1.54,
#   'Country': 'CN',
#   'Date': 1696902033},
#  {'City': 'nova xavantina',
#   'Lat': -52.35,
#   'Lng': -14.6667,
#   'Max Temp': 299.91,
#   'Humidity': 68,
#   'Cloudiness': 41,
#   'Wind Speed': 2.12,
#   'Country': 'BR',
#   'Date': 1696902033},
#  {'City': 'kodiak',
#   'Lat': -152.4072,
#   'Lng': 57.79,
#   'Max Temp': 279.83,
#   'Humidity': 62,
#   'Cloudiness': 4,
#   'Wind Speed': 6.55,
#   'Country': 'US',
#   'Date': 1696901823},
#  {'City': 'kudahuvadhoo',
#   'Lat': 72.8944,
#   'Lng': 2.6708,
#   'Max Temp': 300.88,
#   'Humidity': 79,
#   'Cloudiness': 70,
#   'Wind Speed': 6.89,
#   'Country': 'MV',
#   'Date': 1696902035},
#  {'City': 'neietsu',
#   'Lat': 128.4682,
#   'Lng': 37.1845,
#   'Max Temp': 287.21,
#   'Humidity': 70,
#   'Cloudiness': 61,
#   'Wind Speed': 0.86,
#   'Country': 'KR',
#   'Date': 1696902036},
#  {'City': 'la pineda',
#   'Lat': 1.1852,
#   'Lng': 41.0762,
#   'Max Temp': 293.33,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Country': 'ES',
#   'Date': 1696901877},
#  {'City': 'sitka',
#   'Lat': -135.33,
#   'Lng': 57.0531,
#   'Max Temp': 285.09,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 8.75,
#   'Country': 'US',
#   'Date': 1696902039},
#  {'City': 'kaohsiung',
#   'Lat': 120.3133,
#   'Lng': 22.6163,
#   'Max Temp': 304.12,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 1.03,
#   'Country': 'TW',
#   'Date': 1696901784},
#  {'City': 'terbanggi besar',
#   'Lat': 105.2333,
#   'Lng': -4.8667,
#   'Max Temp': 303.57,
#   'Humidity': 59,
#   'Cloudiness': 29,
#   'Wind Speed': 3.24,
#   'Country': 'ID',
#   'Date': 1696902040},
#  {'City': 'bukama',
#   'Lat': 25.85,
#   'Lng': -9.2,
#   'Max Temp': 294.43,
#   'Humidity': 78,
#   'Cloudiness': 49,
#   'Wind Speed': 0.95,
#   'Country': 'CD',
#   'Date': 1696902041},
#  {'City': 'calbuco',
#   'Lat': -73.1273,
#   'Lng': -41.768,
#   'Max Temp': 281.71,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 2.9,
#   'Country': 'CL',
#   'Date': 1696902042},
#  {'City': 'mount gambier',
#   'Lat': 140.7667,
#   'Lng': -37.8333,
#   'Max Temp': 291.36,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 2.09,
#   'Country': 'AU',
#   'Date': 1696901863},
#  {'City': 'port elizabeth',
#   'Lat': 25.5701,
#   'Lng': -33.918,
#   'Max Temp': 287.09,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.09,
#   'Country': 'ZA',
#   'Date': 1696901713},
#  {'City': 'happy valley-goose bay',
#   'Lat': -60.3315,
#   'Lng': 53.3168,
#   'Max Temp': 286.32,
#   'Humidity': 54,
#   'Cloudiness': 75,
#   'Wind Speed': 3.09,
#   'Country': 'CA',
#   'Date': 1696901887},
#  {'City': 'port mathurin',
#   'Lat': 63.4167,
#   'Lng': -19.6833,
#   'Max Temp': 296.62,
#   'Humidity': 75,
#   'Cloudiness': 65,
#   'Wind Speed': 7.45,
#   'Country': 'MU',
#   'Date': 1696901819},
#  {'City': 'badger',
#   'Lat': -147.5333,
#   'Lng': 64.8,
#   'Max Temp': 273.08,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': 1696901849},
#  {'City': 'lihue',
#   'Lat': -159.3672,
#   'Lng': 21.9789,
#   'Max Temp': 301.92,
#   'Humidity': 64,
#   'Cloudiness': 40,
#   'Wind Speed': 6.69,
#   'Country': 'US',
#   'Date': 1696902046},
#  {'City': 'nevada',
#   'Lat': -116.7512,
#   'Lng': 39.2502,
#   'Max Temp': 287.26,
#   'Humidity': 36,
#   'Cloudiness': 100,
#   'Wind Speed': 7.63,
#   'Country': 'US',
#   'Date': 1696902013},
#  {'City': 'khuzdar',
#   'Lat': 66.6434,
#   'Lng': 27.7384,
#   'Max Temp': 293.78,
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 2.09,
#   'Country': 'PK',
#   'Date': 1696902047},
#  {'City': 'warrnambool',
#   'Lat': 142.4833,
#   'Lng': -38.3833,
#   'Max Temp': 291.68,
#   'Humidity': 65,
#   'Cloudiness': 22,
#   'Wind Speed': 3.84,
#   'Country': 'AU',
#   'Date': 1696901980},
#  {'City': 'yellowknife',
#   'Lat': -114.3525,
#   'Lng': 62.456,
#   'Max Temp': 286.71,
#   'Humidity': 80,
#   'Cloudiness': 20,
#   'Wind Speed': 5.14,
#   'Country': 'CA',
#   'Date': 1696901792},
#  {'City': 'villa gesell',
#   'Lat': -56.973,
#   'Lng': -37.2639,
#   'Max Temp': 288.87,
#   'Humidity': 65,
#   'Cloudiness': 78,
#   'Wind Speed': 4.93,
#   'Country': 'AR',
#   'Date': 1696901830},
#  {'City': 'akrehamn',
#   'Lat': 5.1833,
#   'Lng': 59.2667,
#   'Max Temp': 283.29,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 5.66,
#   'Country': 'NO',
#   'Date': 1696902050},
#  {'City': "arkhangel'sk",
#   'Lat': 40.5433,
#   'Lng': 64.5401,
#   'Max Temp': 276.55,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 1.52,
#   'Country': 'RU',
#   'Date': 1696901911},
#  {'City': 'caleta de carquin',
#   'Lat': -77.6267,
#   'Lng': -11.0925,
#   'Max Temp': 291.74,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 4.3,
#   'Country': 'PE',
#   'Date': 1696902051},
#  {'City': 'yuto',
#   'Lat': -64.4719,
#   'Lng': -23.6434,
#   'Max Temp': 298.4,
#   'Humidity': 53,
#   'Cloudiness': 2,
#   'Wind Speed': 0.52,
#   'Country': 'AR',
#   'Date': 1696902052},
#  {'City': 'malango',
#   'Lat': 119.9001,
#   'Lng': -2.9627,
#   'Max Temp': 300.88,
#   'Humidity': 52,
#   'Cloudiness': 83,
#   'Wind Speed': 2.11,
#   'Country': 'ID',
#   'Date': 1696902053},
#  {'City': 'plainview',
#   'Lat': -73.4673,
#   'Lng': 40.7765,
#   'Max Temp': 287.85,
#   'Humidity': 67,
#   'Cloudiness': 40,
#   'Wind Speed': 1.54,
#   'Country': 'US',
#   'Date': 1696902053},
#  {'City': 'san pedro',
#   'Lat': 121.0167,
#   'Lng': 14.35,
#   'Max Temp': 304.46,
#   'Humidity': 79,
#   'Cloudiness': 40,
#   'Wind Speed': 2.06,
#   'Country': 'PH',
#   'Date': 1696901985},
#  {'City': 'boende',
#   'Lat': 20.8667,
#   'Lng': -0.2167,
#   'Max Temp': 294.7,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 0.97,
#   'Country': 'CD',
#   'Date': 1696902055},
#  {'City': 'feijo',
#   'Lat': -70.3536,
#   'Lng': -8.1642,
#   'Max Temp': 297.58,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 1.72,
#   'Country': 'BR',
#   'Date': 1696902056},
#  {'City': "ust'-uda",
#   'Lat': 103.0304,
#   'Lng': 54.1742,
#   'Max Temp': 281.92,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 0.45,
#   'Country': 'RU',
#   'Date': 1696902056},
#  {'City': 'enewetak',
#   'Lat': 162.3373,
#   'Lng': 11.3474,
#   'Max Temp': 301.68,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 5.86,
#   'Country': 'MH',
#   'Date': 1696902057},
#  {'City': 'nova sintra',
#   'Lat': -24.7167,
#   'Lng': 14.8667,
#   'Max Temp': 297.98,
#   'Humidity': 84,
#   'Cloudiness': 97,
#   'Wind Speed': 2.86,
#   'Country': 'CV',
#   'Date': 1696902058},
#  {'City': 'cumbum',
#   'Lat': 77.3,
#   'Lng': 9.7333,
#   'Max Temp': 298.06,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 1.1,
#   'Country': 'IN',
#   'Date': 1696902058},
#  {'City': 'luganville',
#   'Lat': 167.1667,
#   'Lng': -15.5333,
#   'Max Temp': 298.23,
#   'Humidity': 75,
#   'Cloudiness': 94,
#   'Wind Speed': 5.92,
#   'Country': 'VU',
#   'Date': 1696902059},
#  {'City': 'azhikkal',
#   'Lat': 75.3667,
#   'Lng': 11.9,
#   'Max Temp': 298.51,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 0.98,
#   'Country': 'IN',
#   'Date': 1696902060},
#  {'City': 'dunblane',
#   'Lat': -3.9642,
#   'Lng': 56.1884,
#   'Max Temp': 288.59,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 0.89,
#   'Country': 'GB',
#   'Date': 1696902060},
#  {'City': 'nishinoomote',
#   'Lat': 131,
#   'Lng': 30.7333,
#   'Max Temp': 298.46,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 6.17,
#   'Country': 'JP',
#   'Date': 1696902061},
#  {'City': 'laguna',
#   'Lat': -121.4238,
#   'Lng': 38.421,
#   'Max Temp': 295.45,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 2.57,
#   'Country': 'US',
#   'Date': 1696902062},
#  {'City': 'gurupi',
#   'Lat': -49.0686,
#   'Lng': -11.7292,
#   'Max Temp': 302.74,
#   'Humidity': 47,
#   'Cloudiness': 65,
#   'Wind Speed': 1.73,
#   'Country': 'BR',
#   'Date': 1696902064},
#  {'City': 'ujae',
#   'Lat': 165.7642,
#   'Lng': 8.9322,
#   'Max Temp': 301.6,
#   'Humidity': 77,
#   'Cloudiness': 94,
#   'Wind Speed': 5.52,
#   'Country': 'MH',
#   'Date': 1696902064},
#  {'City': 'rehoboth',
#   'Lat': 17.0833,
#   'Lng': -23.3167,
#   'Max Temp': 293.18,
#   'Humidity': 27,
#   'Cloudiness': 72,
#   'Wind Speed': 2.16,
#   'Country': 'NA',
#   'Date': 1696902065},
#  {'City': 'san juan de miraflores',
#   'Lat': -76.9635,
#   'Lng': -12.1629,
#   'Max Temp': 291.58,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 4.12,
#   'Country': 'PE',
#   'Date': 1696902066},
#  {'City': 'guanica',
#   'Lat': -66.908,
#   'Lng': 17.9716,
#   'Max Temp': 302.54,
#   'Humidity': 49,
#   'Cloudiness': 10,
#   'Wind Speed': 3.07,
#   'Country': 'PR',
#   'Date': 1696902066},
#  {'City': 'wailua homesteads',
#   'Lat': -159.378,
#   'Lng': 22.0669,
#   'Max Temp': 301.59,
#   'Humidity': 71,
#   'Cloudiness': 40,
#   'Wind Speed': 6.69,
#   'Country': 'US',
#   'Date': 1696901824},
#  {'City': 'ojai',
#   'Lat': -119.2429,
#   'Lng': 34.4481,
#   'Max Temp': 294.61,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 0.46,
#   'Country': 'US',
#   'Date': 1696902068},
#  {'City': 'kurgunta',
#   'Lat': 77.35,
#   'Lng': 17.2,
#   'Max Temp': 298.6,
#   'Humidity': 68,
#   'Cloudiness': 26,
#   'Wind Speed': 1.7,
#   'Country': 'IN',
#   'Date': 1696902068},
#  {'City': 'palmer',
#   'Lat': -72.3287,
#   'Lng': 42.1584,
#   'Max Temp': 285.8,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 4.12,
#   'Country': 'US',
#   'Date': 1696902069},
#  {'City': 'hadibu',
#   'Lat': 54.0333,
#   'Lng': 12.65,
#   'Max Temp': 299.73,
#   'Humidity': 81,
#   'Cloudiness': 4,
#   'Wind Speed': 0.42,
#   'Country': 'YE',
#   'Date': 1696902070},
#  {'City': 'tralee',
#   'Lat': -9.7026,
#   'Lng': 52.2704,
#   'Max Temp': 288.16,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 2.5,
#   'Country': 'IE',
#   'Date': 1696902071},
#  {'City': 'egilsstadir',
#   'Lat': -14.3948,
#   'Lng': 65.2653,
#   'Max Temp': 279.1,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 4.12,
#   'Country': 'IS',
#   'Date': 1696902071},
#  {'City': "ivdel'",
#   'Lat': 60.4206,
#   'Lng': 60.6911,
#   'Max Temp': 277.14,
#   'Humidity': 77,
#   'Cloudiness': 94,
#   'Wind Speed': 3.58,
#   'Country': 'RU',
#   'Date': 1696902073},
#  {'City': 'ankang',
#   'Lat': 109.0172,
#   'Lng': 32.68,
#   'Max Temp': 291.1,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 0.64,
#   'Country': 'CN',
#   'Date': 1696901787},
#  {'City': 'hamilton',
#   'Lat': -84.5333,
#   'Lng': 39.1834,
#   'Max Temp': 284.87,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Country': 'US',
#   'Date': 1696901804},
#  {'City': 'arkalyk',
#   'Lat': 66.9114,
#   'Lng': 50.2486,
#   'Max Temp': 289.17,
#   'Humidity': 39,
#   'Cloudiness': 82,
#   'Wind Speed': 9.47,
#   'Country': 'KZ',
#   'Date': 1696902074},
#  {'City': 'chifeng',
#   'Lat': 118.9636,
#   'Lng': 42.2683,
#   'Max Temp': 288.15,
#   'Humidity': 44,
#   'Cloudiness': 63,
#   'Wind Speed': 2.07,
#   'Country': 'CN',
#   'Date': 1696902075},
#  {'City': 'avarua',
#   'Lat': -159.775,
#   'Lng': -21.2078,
#   'Max Temp': 300.18,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 2.06,
#   'Country': 'CK',
#   'Date': 1696901830},
#  {'City': 'beichengqu',
#   'Lat': 113.1536,
#   'Lng': 40.4394,
#   'Max Temp': 284.02,
#   'Humidity': 56,
#   'Cloudiness': 100,
#   'Wind Speed': 1.98,
#   'Country': 'CN',
#   'Date': 1696902077},
#  {'City': 'sur',
#   'Lat': 59.5289,
#   'Lng': 22.5667,
#   'Max Temp': 301.2,
#   'Humidity': 55,
#   'Cloudiness': 5,
#   'Wind Speed': 3.65,
#   'Country': 'OM',
#   'Date': 1696902026},
#  {'City': 'kokopo',
#   'Lat': 152.2633,
#   'Lng': -4.352,
#   'Max Temp': 303.24,
#   'Humidity': 65,
#   'Cloudiness': 60,
#   'Wind Speed': 4,
#   'Country': 'PG',
#   'Date': 1696902078},
#  {'City': 'queenstown',
#   'Lat': 26.8753,
#   'Lng': -31.8976,
#   'Max Temp': 283.48,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 2.22,
#   'Country': 'ZA',
#   'Date': 1696901916},
#  {'City': 'oamaru',
#   'Lat': 170.9801,
#   'Lng': -45.0784,
#   'Max Temp': 286.75,
#   'Humidity': 48,
#   'Cloudiness': 53,
#   'Wind Speed': 5.69,
#   'Country': 'NZ',
#   'Date': 1696902079},
#  {'City': 'chonchi',
#   'Lat': -73.8092,
#   'Lng': -42.6128,
#   'Max Temp': 281.55,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.34,
#   'Country': 'CL',
#   'Date': 1696902080},
#  {'City': 'kenora',
#   'Lat': -94.4337,
#   'Lng': 49.8167,
#   'Max Temp': 279.69,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Country': 'CA',
#   'Date': 1696902081},
#  {'City': 'bekovo',
#   'Lat': 43.712,
#   'Lng': 52.4663,
#   'Max Temp': 275.62,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 6.87,
#   'Country': 'RU',
#   'Date': 1696902081},
#  {'City': 'vorgashor',
#   'Lat': 63.95,
#   'Lng': 67.5833,
#   'Max Temp': 274.27,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 5.46,
#   'Country': 'RU',
#   'Date': 1696902082},
#  {'City': 'moratalla',
#   'Lat': -1.8918,
#   'Lng': 38.1893,
#   'Max Temp': 288.37,
#   'Humidity': 80,
#   'Cloudiness': 66,
#   'Wind Speed': 0.25,
#   'Country': 'ES',
#   'Date': 1696902083},
#  {'City': 'durant',
#   'Lat': -96.3708,
#   'Lng': 33.994,
#   'Max Temp': 297.88,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1696902083},
#  {'City': 'edd',
#   'Lat': 41.6925,
#   'Lng': 13.9297,
#   'Max Temp': 303.84,
#   'Humidity': 67,
#   'Cloudiness': 47,
#   'Wind Speed': 2.18,
#   'Country': 'ER',
#   'Date': 1696902084},
#  {'City': 'oshawa',
#   'Lat': -78.8496,
#   'Lng': 43.9001,
#   'Max Temp': 283.38,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 5.14,
#   'Country': 'CA',
#   'Date': 1696902085},
#  {'City': 'celestun',
#   'Lat': -90.4,
#   'Lng': 20.8667,
#   'Max Temp': 299.91,
#   'Humidity': 87,
#   'Cloudiness': 96,
#   'Wind Speed': 4.89,
#   'Country': 'MX',
#   'Date': 1696902086},
#  {'City': 'petropavlovsk-kamchatsky',
#   'Lat': 158.6483,
#   'Lng': 53.0452,
#   'Max Temp': 281.48,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 3.13,
#   'Country': 'RU',
#   'Date': 1696901801},
#  {'City': 'jamestown',
#   'Lat': -79.2353,
#   'Lng': 42.097,
#   'Max Temp': 281.32,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 4.12,
#   'Country': 'US',
#   'Date': 1696901856},
#  {'City': 'walvis bay',
#   'Lat': 14.5053,
#   'Lng': -22.9575,
#   'Max Temp': 287.68,
#   'Humidity': 88,
#   'Cloudiness': 82,
#   'Wind Speed': 2.57,
#   'Country': 'NA',
#   'Date': 1696902088},
#  {'City': 'lompoc',
#   'Lat': -120.4579,
#   'Lng': 34.6391,
#   'Max Temp': 291.49,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 6.69,
#   'Country': 'US',
#   'Date': 1696902088},
#  {'City': 'santa ana',
#   'Lat': -117.8678,
#   'Lng': 33.7456,
#   'Max Temp': 300.04,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': 1696902088},
#  {'City': 'anadyr',
#   'Lat': 177.4833,
#   'Lng': 64.75,
#   'Max Temp': 273.43,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 1,
#   'Country': 'RU',
#   'Date': 1696902090},
#  {'City': 'san patricio',
#   'Lat': -97.5169,
#   'Lng': 28.017,
#   'Max Temp': 298.06,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 2.26,
#   'Country': 'US',
#   'Date': 1696901903},
#  {'City': "port saint john's",
#   'Lat': 29.5448,
#   'Lng': -31.6229,
#   'Max Temp': 290.26,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 4.71,
#   'Country': 'ZA',
#   'Date': 1696902091},
#  {'City': 'remire-montjoly',
#   'Lat': -52.2667,
#   'Lng': 4.9167,
#   'Max Temp': 296.17,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'GF',
#   'Date': 1696901875},
#  {'City': 'shiyan',
#   'Lat': 110.7781,
#   'Lng': 32.6475,
#   'Max Temp': 291.81,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 1.16,
#   'Country': 'CN',
#   'Date': 1696902047},
#  {'City': 'alto barinas',
#   'Lat': -70.2261,
#   'Lng': 8.5931,
#   'Max Temp': 297.37,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 2.13,
#   'Country': 'VE',
#   'Date': 1696902093},
#  {'City': 'ampanihy',
#   'Lat': 44.75,
#   'Lng': -24.7,
#   'Max Temp': 291.31,
#   'Humidity': 96,
#   'Cloudiness': 41,
#   'Wind Speed': 2.92,
#   'Country': 'MG',
#   'Date': 1696902094},
#  {'City': 'kingscliff',
#   'Lat': 153.5667,
#   'Lng': -28.2667,
#   'Max Temp': 298.68,
#   'Humidity': 53,
#   'Cloudiness': 7,
#   'Wind Speed': 6.69,
#   'Country': 'AU',
#   'Date': 1696902095},
#  {'City': 'callao',
#   'Lat': -77.15,
#   'Lng': -12.0667,
#   'Max Temp': 292.44,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 5.14,
#   'Country': 'PE',
#   'Date': 1696902095},
#  {'City': 'tiksi',
#   'Lat': 128.8694,
#   'Lng': 71.6872,
#   'Max Temp': 264.41,
#   'Humidity': 93,
#   'Cloudiness': 97,
#   'Wind Speed': 3.41,
#   'Country': 'RU',
#   'Date': 1696901838},
#  {'City': 'kiama',
#   'Lat': 150.8667,
#   'Lng': -34.6833,
#   'Max Temp': 291.73,
#   'Humidity': 80,
#   'Cloudiness': 87,
#   'Wind Speed': 3.43,
#   'Country': 'AU',
#   'Date': 1696902097},
#  {'City': 'richards bay',
#   'Lat': 32.0377,
#   'Lng': -28.783,
#   'Max Temp': 292.93,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 1.64,
#   'Country': 'ZA',
#   'Date': 1696902098},
#  {'City': 'cabo san lucas',
#   'Lat': -109.9124,
#   'Lng': 22.8909,
#   'Max Temp': 302.32,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 4.02,
#   'Country': 'MX',
#   'Date': 1696902098},
#  {'City': 'amungan',
#   'Lat': 119.9582,
#   'Lng': 15.3652,
#   'Max Temp': 303.18,
#   'Humidity': 67,
#   'Cloudiness': 85,
#   'Wind Speed': 1.7,
#   'Country': 'PH',
#   'Date': 1696902099},
#  {'City': 'sa kaeo',
#   'Lat': 102.3333,
#   'Lng': 13.75,
#   'Max Temp': 298.75,
#   'Humidity': 89,
#   'Cloudiness': 97,
#   'Wind Speed': 1.82,
#   'Country': 'TH',
#   'Date': 1696902100},
#  {'City': 'marka',
#   'Lat': 44.7717,
#   'Lng': 1.7159,
#   'Max Temp': 298.42,
#   'Humidity': 82,
#   'Cloudiness': 77,
#   'Wind Speed': 5.25,
#   'Country': 'SO',
#   'Date': 1696902100},
#  {'City': 'lake city',
#   'Lat': -82.6393,
#   'Lng': 30.1897,
#   'Max Temp': 289.07,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1696902101},
#  {'City': 'thompson',
#   'Lat': -97.8558,
#   'Lng': 55.7435,
#   'Max Temp': 278.24,
#   'Humidity': 81,
#   'Cloudiness': 20,
#   'Wind Speed': 1.03,
#   'Country': 'CA',
#   'Date': 1696902102},
#  {'City': 'harper',
#   'Lat': -7.7169,
#   'Lng': 4.375,
#   'Max Temp': 298.16,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Country': 'LR',
#   'Date': 1696901889},
#  {'City': 'baglung',
#   'Lat': 83.5898,
#   'Lng': 28.2719,
#   'Max Temp': 294.71,
#   'Humidity': 86,
#   'Cloudiness': 37,
#   'Wind Speed': 0.67,
#   'Country': 'NP',
#   'Date': 1696902103},
#  {'City': "vrangel'",
#   'Lat': 133.0839,
#   'Lng': 42.7297,
#   'Max Temp': 289.82,
#   'Humidity': 53,
#   'Cloudiness': 5,
#   'Wind Speed': 4.76,
#   'Country': 'RU',
#   'Date': 1696902104},
#  {'City': 'lebu',
#   'Lat': -73.65,
#   'Lng': -37.6167,
#   'Max Temp': 283.47,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 4.73,
#   'Country': 'CL',
#   'Date': 1696901883},
#  {'City': 'el fasher',
#   'Lat': 25.3494,
#   'Lng': 13.6279,
#   'Max Temp': 302.8,
#   'Humidity': 24,
#   'Cloudiness': 5,
#   'Wind Speed': 3.08,
#   'Country': 'SD',
#   'Date': 1696902105},
#  {'City': 'katsuren-haebaru',
#   'Lat': 127.8719,
#   'Lng': 26.3369,
#   'Max Temp': 302.36,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 3.6,
#   'Country': 'JP',
#   'Date': 1696902106},
#  {'City': 'tazacorte',
#   'Lat': -17.9293,
#   'Lng': 28.629,
#   'Max Temp': 297.69,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Country': 'ES',
#   'Date': 1696902106},
#  {'City': 'minot air force base',
#   'Lat': -101.3391,
#   'Lng': 48.4209,
#   'Max Temp': 280.25,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': 1696902107},
#  {'City': 'sakaiminato',
#   'Lat': 133.2333,
#   'Lng': 35.55,
#   'Max Temp': 294.14,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 6.17,
#   'Country': 'JP',
#   'Date': 1696902108},
#  {'City': 'klyuchi',
#   'Lat': 79.1667,
#   'Lng': 52.2667,
#   'Max Temp': 286.43,
#   'Humidity': 60,
#   'Cloudiness': 98,
#   'Wind Speed': 4.51,
#   'Country': 'RU',
#   'Date': 1696901885},
#  {'City': 'keban',
#   'Lat': 38.7336,
#   'Lng': 38.7978,
#   'Max Temp': 289.05,
#   'Humidity': 54,
#   'Cloudiness': 4,
#   'Wind Speed': 1.34,
#   'Country': 'TR',
#   'Date': 1696902109},
#  {'City': 'udachny',
#   'Lat': 112.4,
#   'Lng': 66.4167,
#   'Max Temp': 276.18,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.45,
#   'Country': 'RU',
#   'Date': 1696901930},
#  {'City': 'northam',
#   'Lat': -4.2167,
#   'Lng': 51.0333,
#   'Max Temp': 287.4,
#   'Humidity': 97,
#   'Cloudiness': 75,
#   'Wind Speed': 2.06,
#   'Country': 'GB',
#   'Date': 1696902111},
#  {'City': 'burnie',
#   'Lat': 145.9167,
#   'Lng': -41.0667,
#   'Max Temp': 288.12,
#   'Humidity': 51,
#   'Cloudiness': 3,
#   'Wind Speed': 3.63,
#   'Country': 'AU',
#   'Date': 1696901891},
#  {'City': 'kapuskasing',
#   'Lat': -82.4331,
#   'Lng': 49.4169,
#   'Max Temp': 277.2,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3.09,
#   'Country': 'CA',
#   'Date': 1696902112},
#  {'City': 'maintirano',
#   'Lat': 44.0167,
#   'Lng': -18.0667,
#   'Max Temp': 297.96,
#   'Humidity': 79,
#   'Cloudiness': 6,
#   'Wind Speed': 1.72,
#   'Country': 'MG',
#   'Date': 1696902113},
#  {'City': 'ghadamis',
#   'Lat': 9.5007,
#   'Lng': 30.1337,
#   'Max Temp': 294.67,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 3.05,
#   'Country': 'LY',
#   'Date': 1696902113},
#  {'City': 'sajir',
#   'Lat': 44.5996,
#   'Lng': 25.1825,
#   'Max Temp': 298.34,
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 4.54,
#   'Country': 'SA',
#   'Date': 1696902114},
#  {'City': 'aver-o-mar',
#   'Lat': -8.7812,
#   'Lng': 41.4078,
#   'Max Temp': 294.95,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 1.03,
#   'Country': 'PT',
#   'Date': 1696902115},
#  {'City': 'aasiaat',
#   'Lat': -52.8699,
#   'Lng': 68.7098,
#   'Max Temp': 270.55,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 3.78,
#   'Country': 'GL',
#   'Date': 1696901848},
#  {'City': 'ostersund',
#   'Lat': 14.6357,
#   'Lng': 63.1792,
#   'Max Temp': 278.4,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 3.09,
#   'Country': 'SE',
#   'Date': 1696902116},
#  {'City': 'sanctuary point',
#   'Lat': 150.629,
#   'Lng': -35.1114,
#   'Max Temp': 291.59,
#   'Humidity': 68,
#   'Cloudiness': 67,
#   'Wind Speed': 3.69,
#   'Country': 'AU',
#   'Date': 1696902117},
#  {'City': 'kailua-kona',
#   'Lat': -155.9956,
#   'Lng': 19.6406,
#   'Max Temp': 302.19,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 4.63,
#   'Country': 'US',
#   'Date': 1696902118},
#  {'City': 'condoto',
#   'Lat': -76.6497,
#   'Lng': 5.0935,
#   'Max Temp': 297.45,
#   'Humidity': 91,
#   'Cloudiness': 55,
#   'Wind Speed': 1.12,
#   'Country': 'CO',
#   'Date': 1696902118},
#  {'City': 'toledo',
#   'Lat': -4,
#   'Lng': 39.8333,
#   'Max Temp': 292.55,
#   'Humidity': 35,
#   'Cloudiness': 63,
#   'Wind Speed': 2.74,
#   'Country': 'ES',
#   'Date': 1696902119},
#  {'City': 'flying fish cove',
#   'Lat': 105.6791,
#   'Lng': -10.4217,
#   'Max Temp': 298.97,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 4.63,
#   'Country': 'CX',
#   'Date': 1696902119},
#  {'City': 'namdrik',
#   'Lat': 168.1028,
#   'Lng': 5.5994,
#   'Max Temp': 302.48,
#   'Humidity': 70,
#   'Cloudiness': 99,
#   'Wind Speed': 4.11,
#   'Country': 'MH',
#   'Date': 1696902120},
#  {'City': 'georgetown',
#   'Lat': 100.3354,
#   'Lng': 5.4112,
#   'Max Temp': 302.11,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 2.06,
#   'Country': 'MY',
#   'Date': 1696901752},
#  {'City': 'ashkasham',
#   'Lat': 71.5333,
#   'Lng': 36.6833,
#   'Max Temp': 272.72,
#   'Humidity': 73,
#   'Cloudiness': 5,
#   'Wind Speed': 1.57,
#   'Country': 'AF',
#   'Date': 1696902122},
#  {'City': 'borba',
#   'Lat': -59.5939,
#   'Lng': -4.3878,
#   'Max Temp': 303.64,
#   'Humidity': 39,
#   'Cloudiness': 85,
#   'Wind Speed': 1.08,
#   'Country': 'BR',
#   'Date': 1696902122},
#  {'City': 'ostroleka',
#   'Lat': 21.5757,
#   'Lng': 53.0862,
#   'Max Temp': 276.31,
#   'Humidity': 78,
#   'Cloudiness': 15,
#   'Wind Speed': 2.52,
#   'Country': 'PL',
#   'Date': 1696902123},
#  {'City': 'rabo de peixe',
#   'Lat': -25.5833,
#   'Lng': 37.8,
#   'Max Temp': 294.88,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 6.69,
#   'Country': 'PT',
#   'Date': 1696902124},
#  {'City': 'as sulayyil',
#   'Lat': 45.5779,
#   'Lng': 20.4607,
#   'Max Temp': 303.29,
#   'Humidity': 30,
#   'Cloudiness': 21,
#   'Wind Speed': 1.99,
#   'Country': 'SA',
#   'Date': 1696902125},
#  {'City': 'pont rouge',
#   'Lat': -72.0825,
#   'Lng': 48.8833,
#   'Max Temp': 282.31,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 4.65,
#   'Country': 'CA',
#   'Date': 1696902125},
#  {'City': 'nikolayevsk-on-amure',
#   'Lat': 140.73,
#   'Lng': 53.1406,
#   'Max Temp': 281.16,
#   'Humidity': 46,
#   'Cloudiness': 13,
#   'Wind Speed': 6.02,
#   'Country': 'RU',
#   'Date': 1696902126},
#  {'City': 'yinchuan',
#   'Lat': 106.2731,
#   'Lng': 38.4681,
#   'Max Temp': 288.3,
#   'Humidity': 43,
#   'Cloudiness': 38,
#   'Wind Speed': 1.82,
#   'Country': 'CN',
#   'Date': 1696901916},
#  {'City': 'booue',
#   'Lat': 11.9385,
#   'Lng': -0.0921,
#   'Max Temp': 295.6,
#   'Humidity': 99,
#   'Cloudiness': 99,
#   'Wind Speed': 0.44,
#   'Country': 'GA',
#   'Date': 1696902127},
#  {'City': 'powell',
#   'Lat': -83.0752,
#   'Lng': 40.1578,
#   'Max Temp': 285.26,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 2.06,
#   'Country': 'US',
#   'Date': 1696901895},
#  {'City': 'tayshet',
#   'Lat': 98.0044,
#   'Lng': 55.9342,
#   'Max Temp': 284.59,
#   'Humidity': 66,
#   'Cloudiness': 17,
#   'Wind Speed': 2.39,
#   'Country': 'RU',
#   'Date': 1696902129},
#  {'City': 'kitimat',
#   'Lat': -128.6534,
#   'Lng': 54.0524,
#   'Max Temp': 285.36,
#   'Humidity': 63,
#   'Cloudiness': 71,
#   'Wind Speed': 0.89,
#   'Country': 'CA',
#   'Date': 1696902129},
#  {'City': 'srivardhan',
#   'Lat': 73.0167,
#   'Lng': 18.0333,
#   'Max Temp': 298.73,
#   'Humidity': 86,
#   'Cloudiness': 29,
#   'Wind Speed': 1.98,
#   'Country': 'IN',
#   'Date': 1696902125},
#  {'City': 'tagbina',
#   'Lat': 126.1714,
#   'Lng': 8.4519,
#   'Max Temp': 303.59,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 1.34,
#   'Country': 'PH',
#   'Date': 1696902130},
#  {'City': 'keflavik',
#   'Lat': -22.5624,
#   'Lng': 64.0049,
#   'Max Temp': 278.1,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 14.92,
#   'Country': 'IS',
#   'Date': 1696902131},
#  {'City': 'warwick',
#   'Lat': -71.4162,
#   'Lng': 41.7001,
#   'Max Temp': 287.53,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 5.36,
#   'Country': 'US',
#   'Date': 1696902101},
#  {'City': 'port alfred',
#   'Lat': 26.891,
#   'Lng': -33.5906,
#   'Max Temp': 286.58,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 5.07,
#   'Country': 'ZA',
#   'Date': 1696901872},
#  {'City': 'altay',
#   'Lat': 88.1167,
#   'Lng': 47.8667,
#   'Max Temp': 284.64,
#   'Humidity': 53,
#   'Cloudiness': 9,
#   'Wind Speed': 2.3,
#   'Country': 'CN',
#   'Date': 1696902133},
#  {'City': 'igbo-ora',
#   'Lat': 3.2833,
#   'Lng': 7.4333,
#   'Max Temp': 296.55,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 1.8,
#   'Country': 'NG',
#   'Date': 1696902134},
#  {'City': 'galliano',
#   'Lat': -90.2992,
#   'Lng': 29.4422,
#   'Max Temp': 292.04,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'US',
#   'Date': 1696902134},
#  {'City': 'vorkuta',
#   'Lat': 64,
#   'Lng': 67.5,
#   'Max Temp': 274.39,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 5.18,
#   'Country': 'RU',
#   'Date': 1696901939},
#  {'City': 'makokou',
#   'Lat': 12.8642,
#   'Lng': 0.5738,
#   'Max Temp': 293.72,
#   'Humidity': 98,
#   'Cloudiness': 98,
#   'Wind Speed': 0.92,
#   'Country': 'GA',
#   'Date': 1696902136},
#  {'City': 'broken hill',
#   'Lat': 141.4333,
#   'Lng': -31.95,
#   'Max Temp': 296.53,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 2.99,
#   'Country': 'AU',
#   'Date': 1696902064},
#  {'City': 'mount pearl',
#   'Lat': -52.7813,
#   'Lng': 47.5166,
#   'Max Temp': 283.23,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 3.09,
#   'Country': 'CA',
#   'Date': 1696902129},
# ...
#  {'City': 'quesada',
#   'Lat': -84.4271,
#   'Lng': 10.3238,
#   'Max Temp': 297.88,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 1.18,
#   'Country': 'CR',
#   'Date': 1696902305},
#  {'City': 'vila velha',
#   'Lat': -40.2925,
#   'Lng': -20.3297,
#   'Max Temp': 298.12,
#   'Humidity': 87,
#   'Cloudiness': 40,
#   'Wind Speed': 4.63,
#   'Country': 'BR',
#   'Date': 1696902268},
#  {'City': 'mugia',
#   'Lat': -9.2179,
#   'Lng': 43.1041,
#   'Max Temp': 293.22,
#   'Humidity': 53,
#   'Cloudiness': 6,
#   'Wind Speed': 2.05,
#   'Country': 'ES',
#   'Date': 1696902306},
#  {'City': 'forbesganj',
#   'Lat': 87.25,
#   'Lng': 26.3,
#   'Max Temp': 298.21,
#   'Humidity': 85,
#   'Cloudiness': 92,
#   'Wind Speed': 3.18,
#   'Country': 'IN',
#   'Date': 1696902307},
#  {'City': 'znomenka',
#   'Lat': 32.6647,
#   'Lng': 48.7128,
#   'Max Temp': 275.69,
#   'Humidity': 50,
#   'Cloudiness': 12,
#   'Wind Speed': 2.81,
#   'Country': 'UA',
#   'Date': 1696902065},
#  {'City': 'nalgonda',
#   'Lat': 79.2667,
#   'Lng': 17.05,
#   'Max Temp': 299.36,
#   'Humidity': 74,
#   'Cloudiness': 94,
#   'Wind Speed': 2,
#   'Country': 'IN',
#   'Date': 1696901835},
#  {'City': 'atafu village',
#   'Lat': -172.5159,
#   'Lng': -8.5421,
#   'Max Temp': 302.25,
#   'Humidity': 75,
#   'Cloudiness': 93,
#   'Wind Speed': 6.13,
#   'Country': 'TK',
#   'Date': 1696902309},
#  {'City': 'rawlins',
#   'Lat': -107.2387,
#   'Lng': 41.7911,
#   'Max Temp': 286.12,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': 1696902310},
#  {'City': 'onega',
#   'Lat': 38.1404,
#   'Lng': 63.9061,
#   'Max Temp': 276.9,
#   'Humidity': 82,
#   'Cloudiness': 99,
#   'Wind Speed': 4.02,
#   'Country': 'RU',
#   'Date': 1696902237},
#  {'City': 'sarina',
#   'Lat': 149.2167,
#   'Lng': -21.4333,
#   'Max Temp': 299.05,
#   'Humidity': 15,
#   'Cloudiness': 1,
#   'Wind Speed': 4.72,
#   'Country': 'AU',
#   'Date': 1696902311},
#  {'City': 'jimma',
#   'Lat': 36.8333,
#   'Lng': 7.6667,
#   'Max Temp': 286.91,
#   'Humidity': 80,
#   'Cloudiness': 94,
#   'Wind Speed': 0.8,
#   'Country': 'ET',
#   'Date': 1696902265},
#  {'City': 'baardheere',
#   'Lat': 42.2764,
#   'Lng': 2.3446,
#   'Max Temp': 297.88,
#   'Humidity': 74,
#   'Cloudiness': 28,
#   'Wind Speed': 5.14,
#   'Country': 'SO',
#   'Date': 1696902313},
#  {'City': 'madaoua',
#   'Lat': 5.96,
#   'Lng': 14.073,
#   'Max Temp': 303.5,
#   'Humidity': 23,
#   'Cloudiness': 39,
#   'Wind Speed': 2.95,
#   'Country': 'NE',
#   'Date': 1696902313},
#  {'City': 'kourou',
#   'Lat': -52.6478,
#   'Lng': 5.1552,
#   'Max Temp': 296.18,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 3.41,
#   'Country': 'GF',
#   'Date': 1696901896},
#  {'City': 'kaka',
#   'Lat': 59.6143,
#   'Lng': 37.3482,
#   'Max Temp': 294.71,
#   'Humidity': 27,
#   'Cloudiness': 2,
#   'Wind Speed': 4.72,
#   'Country': 'TM',
#   'Date': 1696902314},
#  {'City': 'euclid',
#   'Lat': -81.5268,
#   'Lng': 41.5931,
#   'Max Temp': 286.06,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 6.69,
#   'Country': 'US',
#   'Date': 1696902201},
#  {'City': 'ylitornio',
#   'Lat': 23.6773,
#   'Lng': 66.3089,
#   'Max Temp': 271.22,
#   'Humidity': 89,
#   'Cloudiness': 6,
#   'Wind Speed': 1.11,
#   'Country': 'FI',
#   'Date': 1696902317},
#  {'City': 'nsunga',
#   'Lat': 31.3947,
#   'Lng': -1.1439,
#   'Max Temp': 292.62,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 1.87,
#   'Country': 'TZ',
#   'Date': 1696902318},
#  {'City': 'yuzhno-kurilsk',
#   'Lat': 145.8556,
#   'Lng': 44.0306,
#   'Max Temp': 285.03,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 3.16,
#   'Country': 'RU',
#   'Date': 1696902318},
#  {'City': 'aioun',
#   'Lat': -9.6149,
#   'Lng': 16.6614,
#   'Max Temp': 303.9,
#   'Humidity': 32,
#   'Cloudiness': 6,
#   'Wind Speed': 3.21,
#   'Country': 'MR',
#   'Date': 1696902320},
#  {'City': 'igrim',
#   'Lat': 64.4162,
#   'Lng': 63.1906,
#   'Max Temp': 275.94,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 5.81,
#   'Country': 'RU',
#   'Date': 1696901843},
#  {'City': 'jawf al maqbabah',
#   'Lat': 45.8349,
#   'Lng': 13.8378,
#   'Max Temp': 295.86,
#   'Humidity': 67,
#   'Cloudiness': 5,
#   'Wind Speed': 1.21,
#   'Country': 'YE',
#   'Date': 1696902321},
#  {'City': 'peniche',
#   'Lat': -9.3811,
#   'Lng': 39.3558,
#   'Max Temp': 292.64,
#   'Humidity': 94,
#   'Cloudiness': 6,
#   'Wind Speed': 3.5,
#   'Country': 'PT',
#   'Date': 1696902322},
#  {'City': 'aykhal',
#   'Lat': 111.5,
#   'Lng': 66,
#   'Max Temp': 275.97,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 6.26,
#   'Country': 'RU',
#   'Date': 1696902322},
#  {'City': 'bumba',
#   'Lat': 22.4667,
#   'Lng': 2.1833,
#   'Max Temp': 295.05,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 0.94,
#   'Country': 'CD',
#   'Date': 1696902265},
#  {'City': 'island harbour',
#   'Lat': -1.2758,
#   'Lng': 50.724,
#   'Max Temp': 289.78,
#   'Humidity': 96,
#   'Cloudiness': 96,
#   'Wind Speed': 3.7,
#   'Country': 'GB',
#   'Date': 1696902324},
#  {'City': 'puerto armuelles',
#   'Lat': -82.8667,
#   'Lng': 8.2833,
#   'Max Temp': 302.13,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 2.24,
#   'Country': 'PA',
#   'Date': 1696902081},
#  {'City': 'castillos',
#   'Lat': -53.8333,
#   'Lng': -34.1667,
#   'Max Temp': 285.95,
#   'Humidity': 73,
#   'Cloudiness': 1,
#   'Wind Speed': 3.42,
#   'Country': 'UY',
#   'Date': 1696902325},
#  {'City': 'nacala',
#   'Lat': 40.6728,
#   'Lng': -14.5428,
#   'Max Temp': 295.64,
#   'Humidity': 91,
#   'Cloudiness': 2,
#   'Wind Speed': 0.3,
#   'Country': 'MZ',
#   'Date': 1696902325},
#  {'City': 'la gi',
#   'Lat': 107.7833,
#   'Lng': 10.6667,
#   'Max Temp': 302.08,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 1.42,
#   'Country': 'VN',
#   'Date': 1696902327},
#  {'City': 'shalqar',
#   'Lat': 59.6,
#   'Lng': 47.8333,
#   'Max Temp': 281.87,
#   'Humidity': 53,
#   'Cloudiness': 100,
#   'Wind Speed': 7.99,
#   'Country': 'KZ',
#   'Date': 1696902327},
#  {'City': 'westport',
#   'Lat': -73.3579,
#   'Lng': 41.1415,
#   'Max Temp': 287.02,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 2.06,
#   'Country': 'US',
#   'Date': 1696902069},
#  {'City': 'ar rutbah',
#   'Lat': 40.2848,
#   'Lng': 33.0381,
#   'Max Temp': 299.3,
#   'Humidity': 31,
#   'Cloudiness': 100,
#   'Wind Speed': 0.92,
#   'Country': 'IQ',
#   'Date': 1696902329},
#  {'City': 'sena madureira',
#   'Lat': -68.6569,
#   'Lng': -9.0656,
#   'Max Temp': 298.82,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 1.82,
#   'Country': 'BR',
#   'Date': 1696902205},
#  {'City': 'suntar',
#   'Lat': 117.6319,
#   'Lng': 62.1444,
#   'Max Temp': 277.12,
#   'Humidity': 90,
#   'Cloudiness': 99,
#   'Wind Speed': 2.68,
#   'Country': 'RU',
#   'Date': 1696902330},
#  {'City': 'belyayevka',
#   'Lat': 56.4096,
#   'Lng': 51.3974,
#   'Max Temp': 276.19,
#   'Humidity': 75,
#   'Cloudiness': 5,
#   'Wind Speed': 4.55,
#   'Country': 'RU',
#   'Date': 1696902331},
#  {'City': 'fortaleza',
#   'Lat': -38.5247,
#   'Lng': -3.7227,
#   'Max Temp': 300.49,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 5.66,
#   'Country': 'BR',
#   'Date': 1696902331},
#  {'City': 'kone',
#   'Lat': 164.8658,
#   'Lng': -21.0595,
#   'Max Temp': 297.35,
#   'Humidity': 51,
#   'Cloudiness': 91,
#   'Wind Speed': 0.96,
#   'Country': 'NC',
#   'Date': 1696902332},
#  {'City': 'ternate',
#   'Lat': 127.4,
#   'Lng': 0.8,
#   'Max Temp': 301.3,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 7.1,
#   'Country': 'ID',
#   'Date': 1696902333},
#  {'City': 'pimentel',
#   'Lat': -79.9342,
#   'Lng': -6.8367,
#   'Max Temp': 294.31,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 8.23,
#   'Country': 'PE',
#   'Date': 1696902334},
#  {'City': 'josenii bargaului',
#   'Lat': 24.6833,
#   'Lng': 47.2167,
#   'Max Temp': 277.8,
#   'Humidity': 75,
#   'Cloudiness': 81,
#   'Wind Speed': 0.56,
#   'Country': 'RO',
#   'Date': 1696902334},
#  {'City': 'maicao',
#   'Lat': -72.2432,
#   'Lng': 11.3832,
#   'Max Temp': 300.46,
#   'Humidity': 84,
#   'Cloudiness': 30,
#   'Wind Speed': 1.76,
#   'Country': 'CO',
#   'Date': 1696902335},
#  {'City': 'el sauzal de rodriguez',
#   'Lat': -116.6833,
#   'Lng': 31.9,
#   'Max Temp': 291.71,
#   'Humidity': 80,
#   'Cloudiness': 39,
#   'Wind Speed': 2.1,
#   'Country': 'MX',
#   'Date': 1696902336},
#  {'City': 'kijang',
#   'Lat': 129.2139,
#   'Lng': 35.2442,
#   'Max Temp': 293,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 3.21,
#   'Country': 'KR',
#   'Date': 1696902337},
#  {'City': 'ca mau',
#   'Lat': 105.15,
#   'Lng': 9.1769,
#   'Max Temp': 303.47,
#   'Humidity': 67,
#   'Cloudiness': 96,
#   'Wind Speed': 2.69,
#   'Country': 'VN',
#   'Date': 1696902294},
#  {'City': 'saint-mandrier-sur-mer',
#   'Lat': 5.929,
#   'Lng': 43.078,
#   'Max Temp': 293.58,
#   'Humidity': 80,
#   'Cloudiness': 5,
#   'Wind Speed': 1.54,
#   'Country': 'FR',
#   'Date': 1696902338},
#  {'City': 'tshela',
#   'Lat': 12.9333,
#   'Lng': -4.9833,
#   'Max Temp': 295.52,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 0.41,
#   'Country': 'CD',
#   'Date': 1696902339},
#  {'City': 'tadine',
#   'Lat': 167.8833,
#   'Lng': -21.55,
#   'Max Temp': 296.16,
#   'Humidity': 54,
#   'Cloudiness': 72,
#   'Wind Speed': 4.57,
#   'Country': 'NC',
#   'Date': 1696902339},
#  {'City': 'oral',
#   'Lat': 51.3667,
#   'Lng': 51.2333,
#   'Max Temp': 278.14,
#   'Humidity': 81,
#   'Cloudiness': 40,
#   'Wind Speed': 6,
#   'Country': 'KZ',
#   'Date': 1696902340},
#  {'City': 'reitz',
#   'Lat': 28.4273,
#   'Lng': -27.8014,
#   'Max Temp': 287.35,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 2.08,
#   'Country': 'ZA',
#   'Date': 1696902194},
#  {'City': 'stari kuty',
#   'Lat': 25.1729,
#   'Lng': 48.2709,
#   'Max Temp': 277.86,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 0.71,
#   'Country': 'UA',
#   'Date': 1696902341},
#  {'City': 'kegen',
#   'Lat': 79.2203,
#   'Lng': 43.0197,
#   'Max Temp': 280.01,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 2.68,
#   'Country': 'KZ',
#   'Date': 1696902342},
#  {'City': 'tura',
#   'Lat': 90.2201,
#   'Lng': 25.5198,
#   'Max Temp': 297.02,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 0.9,
#   'Country': 'IN',
#   'Date': 1696901594},
#  {'City': 'saldanha',
#   'Lat': 17.9442,
#   'Lng': -33.0117,
#   'Max Temp': 287.18,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 4.24,
#   'Country': 'ZA',
#   'Date': 1696902344},
#  {'City': 'giyani',
#   'Lat': 30.7187,
#   'Lng': -23.3025,
#   'Max Temp': 290.27,
#   'Humidity': 80,
#   'Cloudiness': 8,
#   'Wind Speed': 0.74,
#   'Country': 'ZA',
#   'Date': 1696902345},
#  {'City': 'gardnerville ranchos',
#   'Lat': -119.7413,
#   'Lng': 38.8882,
#   'Max Temp': 291.91,
#   'Humidity': 32,
#   'Cloudiness': 75,
#   'Wind Speed': 3.13,
#   'Country': 'US',
#   'Date': 1696902346},
#  {'City': 'da nang',
#   'Lat': 108.2208,
#   'Lng': 16.0678,
#   'Max Temp': 298.14,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 2.06,
#   'Country': 'VN',
#   'Date': 1696902294},
#  {'City': 'yeed',
#   'Lat': 43.0333,
#   'Lng': 4.55,
#   'Max Temp': 297.71,
#   'Humidity': 65,
#   'Cloudiness': 8,
#   'Wind Speed': 5.12,
#   'Country': 'SO',
#   'Date': 1696902347},
#  {'City': 'tucupita',
#   'Lat': -62.051,
#   'Lng': 9.0622,
#   'Max Temp': 298.82,
#   'Humidity': 86,
#   'Cloudiness': 7,
#   'Wind Speed': 1.79,
#   'Country': 'VE',
#   'Date': 1696902348},
#  {'City': 'agadez',
#   'Lat': 10.25,
#   'Lng': 19.75,
#   'Max Temp': 295.92,
#   'Humidity': 23,
#   'Cloudiness': 3,
#   'Wind Speed': 5.02,
#   'Country': 'NE',
#   'Date': 1696902253},
#  {'City': 'antofagasta',
#   'Lat': -70.4,
#   'Lng': -23.65,
#   'Max Temp': 289.75,
#   'Humidity': 84,
#   'Cloudiness': 30,
#   'Wind Speed': 2.77,
#   'Country': 'CL',
#   'Date': 1696902349},
#  {'City': 'mwene-ditu',
#   'Lat': 23.45,
#   'Lng': -7,
#   'Max Temp': 292.53,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.33,
#   'Country': 'CD',
#   'Date': 1696902350},
#  {'City': 'lamu',
#   'Lat': 40.902,
#   'Lng': -2.2717,
#   'Max Temp': 296.27,
#   'Humidity': 82,
#   'Cloudiness': 91,
#   'Wind Speed': 4.37,
#   'Country': 'KE',
#   'Date': 1696902352},
#  {'City': 'cannonvale',
#   'Lat': 148.7,
#   'Lng': -20.2833,
#   'Max Temp': 297.81,
#   'Humidity': 56,
#   'Cloudiness': 2,
#   'Wind Speed': 6.45,
#   'Country': 'AU',
#   'Date': 1696902353},
#  {'City': 'takhatpur',
#   'Lat': 81.8667,
#   'Lng': 22.15,
#   'Max Temp': 297.84,
#   'Humidity': 70,
#   'Cloudiness': 11,
#   'Wind Speed': 1.07,
#   'Country': 'IN',
#   'Date': 1696902122},
#  {'City': 'marica',
#   'Lat': -42.8186,
#   'Lng': -22.9194,
#   'Max Temp': 297.12,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 3.37,
#   'Country': 'BR',
#   'Date': 1696902355},
#  {'City': 'puerto lempira',
#   'Lat': -83.7667,
#   'Lng': 15.2667,
#   'Max Temp': 300.32,
#   'Humidity': 85,
#   'Cloudiness': 78,
#   'Wind Speed': 2.76,
#   'Country': 'HN',
#   'Date': 1696902356},
#  {'City': 'amga',
#   'Lat': 131.9608,
#   'Lng': 60.8953,
#   'Max Temp': 272.58,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 1.34,
#   'Country': 'RU',
#   'Date': 1696901897},
#  {'City': 'sinop',
#   'Lat': 34.8709,
#   'Lng': 41.7711,
#   'Max Temp': 281.75,
#   'Humidity': 88,
#   'Cloudiness': 99,
#   'Wind Speed': 1.24,
#   'Country': 'TR',
#   'Date': 1696902357},
#  {'City': 'pocao de pedras',
#   'Lat': -44.85,
#   'Lng': -4.6667,
#   'Max Temp': 300.6,
#   'Humidity': 47,
#   'Cloudiness': 1,
#   'Wind Speed': 1.47,
#   'Country': 'BR',
#   'Date': 1696902357},
#  {'City': 'igarka',
#   'Lat': 86.5833,
#   'Lng': 67.4667,
#   'Max Temp': 280.34,
#   'Humidity': 85,
#   'Cloudiness': 81,
#   'Wind Speed': 7.98,
#   'Country': 'RU',
#   'Date': 1696902358},
#  {'City': 'sandnessjoen',
#   'Lat': 12.6316,
#   'Lng': 66.0217,
#   'Max Temp': 274.44,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 5.77,
#   'Country': 'NO',
#   'Date': 1696902359},
#  {'City': 'kuanda',
#   'Lat': 116.0806,
#   'Lng': 56.3161,
#   'Max Temp': 281.13,
#   'Humidity': 64,
#   'Cloudiness': 81,
#   'Wind Speed': 1.25,
#   'Country': 'RU',
#   'Date': 1696902359},
#  {'City': 'gobabis',
#   'Lat': 18.9667,
#   'Lng': -22.45,
#   'Max Temp': 291.98,
#   'Humidity': 22,
#   'Cloudiness': 60,
#   'Wind Speed': 4.9,
#   'Country': 'NA',
#   'Date': 1696902360},
#  {'City': 'nikel',
#   'Lat': 30.222,
#   'Lng': 69.4128,
#   'Max Temp': 271.25,
#   'Humidity': 86,
#   'Cloudiness': 22,
#   'Wind Speed': 2.52,
#   'Country': 'RU',
#   'Date': 1696902361},
#  {'City': 'manaure',
#   'Lat': -72.4445,
#   'Lng': 11.7751,
#   'Max Temp': 302.66,
#   'Humidity': 79,
#   'Cloudiness': 6,
#   'Wind Speed': 2.69,
#   'Country': 'CO',
#   'Date': 1696902362},
#  {'City': 'estes park',
#   'Lat': -105.5217,
#   'Lng': 40.3772,
#   'Max Temp': 287.02,
#   'Humidity': 36,
#   'Cloudiness': 56,
#   'Wind Speed': 1.79,
#   'Country': 'US',
#   'Date': 1696902362},
#  {'City': 'taksimo',
#   'Lat': 114.8794,
#   'Lng': 56.3444,
#   'Max Temp': 282.11,
#   'Humidity': 67,
#   'Cloudiness': 79,
#   'Wind Speed': 0.55,
#   'Country': 'RU',
#   'Date': 1696902363},
#  {'City': 'argo',
#   'Lat': 22.7333,
#   'Lng': 37.6333,
#   'Max Temp': 292.65,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 1.26,
#   'Country': 'GR',
#   'Date': 1696902229},
#  {'City': 'taro',
#   'Lat': 115.28,
#   'Lng': -8.3862,
#   'Max Temp': 298.15,
#   'Humidity': 47,
#   'Cloudiness': 21,
#   'Wind Speed': 1.87,
#   'Country': 'ID',
#   'Date': 1696902365},
#  {'City': 'abou el hassan',
#   'Lat': 1.1962,
#   'Lng': 36.4166,
#   'Max Temp': 292.84,
#   'Humidity': 87,
#   'Cloudiness': 87,
#   'Wind Speed': 2.09,
#   'Country': 'DZ',
#   'Date': 1696902366},
#  {'City': 'sierra grande',
#   'Lat': -65.3557,
#   'Lng': -41.606,
#   'Max Temp': 289.32,
#   'Humidity': 27,
#   'Cloudiness': 99,
#   'Wind Speed': 3.34,
#   'Country': 'AR',
#   'Date': 1696902366},
#  {'City': 'borogontsy',
#   'Lat': 131.1683,
#   'Lng': 62.6683,
#   'Max Temp': 274.42,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 1.79,
#   'Country': 'RU',
#   'Date': 1696902367},
#  {'City': 'bathsheba',
#   'Lat': -59.5167,
#   'Lng': 13.2167,
#   'Max Temp': 301.49,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 5.66,
#   'Country': 'BB',
#   'Date': 1696902368},
#  {'City': 'rio grande',
#   'Lat': -52.0986,
#   'Lng': -32.035,
#   'Max Temp': 289.23,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 4.4,
#   'Country': 'BR',
#   'Date': 1696902076},
#  {'City': 'zaigrayevo',
#   'Lat': 108.2703,
#   'Lng': 51.8336,
#   'Max Temp': 284.18,
#   'Humidity': 65,
#   'Cloudiness': 5,
#   'Wind Speed': 2,
#   'Country': 'RU',
#   'Date': 1696902369},
#  {'City': 'ormara',
#   'Lat': 64.6357,
#   'Lng': 25.2088,
#   'Max Temp': 300,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 5.92,
#   'Country': 'PK',
#   'Date': 1696902370},
#  {'City': 'chiredzi',
#   'Lat': 31.6667,
#   'Lng': -21.05,
#   'Max Temp': 291.88,
#   'Humidity': 81,
#   'Cloudiness': 32,
#   'Wind Speed': 2.46,
#   'Country': 'ZW',
#   'Date': 1696901950}]

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          581
# Lat           581
# Lng           581
# Max Temp      581
# Humidity      581
# Cloudiness    581
# Wind Speed    581
# Country       581
# Date          581
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City       Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     bilibino  166.4372  68.0546    264.79        93          99        0.57
# 1    grytviken  -36.5092 -54.2811    273.05        77          26        4.72
# 2   abu jibeha   31.2285  11.4562    298.79        56         100        2.31
# 3  olonkinbyen   -8.7187  70.9221    275.14        93         100        6.84
# 4  vilyuchinsk  158.4028  52.9306    282.30        82         100        2.05
#
#   Country        Date
# 0      RU  1696901893
# 1      GS  1696901841
# 2      SD  1696901952
# 3      SJ  1696901944
# 4      RU  1696901937

# %%
#Creating a directory to store the city_Data csv file if the directory does not exist
outdir = 'output_data'
if not os.path.exists(outdir):
    os.mkdir(outdir)

# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City       Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           bilibino  166.4372  68.0546    264.79        93          99
# 1          grytviken  -36.5092 -54.2811    273.05        77          26
# 2         abu jibeha   31.2285  11.4562    298.79        56         100
# 3        olonkinbyen   -8.7187  70.9221    275.14        93         100
# 4        vilyuchinsk  158.4028  52.9306    282.30        82         100
#
#          Wind Speed Country        Date
# City_ID
# 0              0.57      RU  1696901893
# 1              4.72      GS  1696901841
# 2              2.31      SD  1696901952
# 3              6.84      SJ  1696901944
# 4              2.05      RU  1696901937

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
