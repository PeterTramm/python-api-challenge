# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os
from scipy.stats import linregress


# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
weather_api_key
# Out:
# 'b0a45ae433134b95fe576791fc1d2bf3'

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 608

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Set the measurment to celsius 
measurement = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "q=" + city + "&appid=" + weather_api_key + "&units=" + measurement
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lon']
        city_lng = city_weather['coord']['lat']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bilibino
# Processing Record 2 of Set 1 | grytviken
# Processing Record 3 of Set 1 | abu jibeha
# Processing Record 4 of Set 1 | olonkinbyen
# Processing Record 5 of Set 1 | vilyuchinsk
# Processing Record 6 of Set 1 | lyubinskiy
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | qaqortoq
# Processing Record 11 of Set 1 | adamstown
# Processing Record 12 of Set 1 | newnham
# Processing Record 13 of Set 1 | tay ninh
# Processing Record 14 of Set 1 | hirtshals
# Processing Record 15 of Set 1 | blackmans bay
# Processing Record 16 of Set 1 | port lincoln
# Processing Record 17 of Set 1 | hassi messaoud
# Processing Record 18 of Set 1 | lionel town
# Processing Record 19 of Set 1 | santa ines
# Processing Record 20 of Set 1 | ribeira grande
# Processing Record 21 of Set 1 | ilulissat
# ...

# %%
city_data
# Out:
# [{'City': 'bilibino',
#   'Lat': 166.4372,
#   'Lng': 68.0546,
#   'Max Temp': -8.36,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 0.58,
#   'Country': 'RU',
#   'Date': 1696905256},
#  {'City': 'grytviken',
#   'Lat': -36.5092,
#   'Lng': -54.2811,
#   'Max Temp': 0.32,
#   'Humidity': 78,
#   'Cloudiness': 45,
#   'Wind Speed': 4.94,
#   'Country': 'GS',
#   'Date': 1696905256},
#  {'City': 'abu jibeha',
#   'Lat': 31.2285,
#   'Lng': 11.4562,
#   'Max Temp': 25.24,
#   'Humidity': 58,
#   'Cloudiness': 79,
#   'Wind Speed': 2.06,
#   'Country': 'SD',
#   'Date': 1696905257},
#  {'City': 'olonkinbyen',
#   'Lat': -8.7187,
#   'Lng': 70.9221,
#   'Max Temp': 2.55,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 6.64,
#   'Country': 'SJ',
#   'Date': 1696905258},
#  {'City': 'vilyuchinsk',
#   'Lat': 158.4028,
#   'Lng': 52.9306,
#   'Max Temp': 7.18,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 2.28,
#   'Country': 'RU',
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          581
# Lat           581
# Lng           581
# Max Temp      581
# Humidity      581
# Cloudiness    581
# Wind Speed    581
# Country       581
# Date          581
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#           City       Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     bilibino  166.4372  68.0546     -8.36        96          99        0.58
# 1    grytviken  -36.5092 -54.2811      0.32        78          45        4.94
# 2   abu jibeha   31.2285  11.4562     25.24        58          79        2.06
# 3  olonkinbyen   -8.7187  70.9221      2.55        89         100        6.64
# 4  vilyuchinsk  158.4028  52.9306      7.18        84         100        2.28
#
#   Country        Date
# 0      RU  1696905256
# 1      GS  1696905256
# 2      SD  1696905257
# 3      SJ  1696905258
# 4      RU  1696905258

# %%
#Creating a directory to store the city_Data csv file if the directory does not exist
outdir = '../output_data'
if not os.path.exists(outdir):
    os.mkdir(outdir)

# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City       Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           bilibino  166.4372  68.0546     -8.36        96          99
# 1          grytviken  -36.5092 -54.2811      0.32        78          45
# 2         abu jibeha   31.2285  11.4562     25.24        58          79
# 3        olonkinbyen   -8.7187  70.9221      2.55        89         100
# 4        vilyuchinsk  158.4028  52.9306      7.18        84         100
#
#          Wind Speed Country        Date
# City_ID
# 0              0.58      RU  1696905256
# 1              4.94      GS  1696905256
# 2              2.06      SD  1696905257
# 3              6.64      SJ  1696905258
# 4              2.28      RU  1696905258

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_axis = city_data_df['Lat']
y_axis = city_data_df['Max Temp']

plt.scatter(x_axis,y_axis, s= 10)

# Incorporate the other graph properties
plt.grid()
plt.xlabel("Lattitude")
plt.ylabel("Max Temperature (C)")
plt.title("Latitude vs City Max Tempearture (10/10/2023)")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_axis = city_data_df['Lat']
y_axis = city_data_df['Humidity']

plt.scatter(x_axis,y_axis, s= 10)

# Incorporate the other graph properties
plt.grid()
plt.xlabel("Lattitude")
plt.ylabel("Humidity (%)")
plt.title("Latitude vs Humidity (10/10/2023)")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_axis = city_data_df['Lat']
y_axis = city_data_df['Cloudiness']

plt.scatter(x_axis,y_axis, s= 10)

# Incorporate the other graph properties
plt.grid()
plt.xlabel("Lattitude")
plt.ylabel("Cloudiness (%)")
plt.title("Latitude vs cloudiness (10/10/2023)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_axis = city_data_df['Lat']
y_axis = city_data_df['Wind Speed']

plt.scatter(x_axis,y_axis, s= 10)

# Incorporate the other graph properties
plt.grid()
plt.xlabel("Lattitude")
plt.ylabel("Cloudiness (meter/sec)")
plt.title("Latitude vs Wind Speed  (10/10/2023)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %%
# Out:
# City_ID
# 0      166.4372
# 1      -36.5092
# 2       31.2285
# 3       -8.7187
# 4      158.4028
#          ...
# 576    -59.5167
# 577    -52.0986
# 578    108.2703
# 579     64.6357
# 580     31.6667
# Name: Lat, Length: 581, dtype: float64

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def Line_Regress(x_axis,y_axis):
    (slope,intercept,rvalue,pvalue,stderr) = linregress(x_axis,y_axis)
    regress_value = x_axis*slope + intercept
    line_equation = f"y = {round(slope,2)}x + {round(intercept,2)}"
    
    #Plotting graph 
    plt.scatter(x_axis,y_axis, s= 30)
    plt.plot(x_axis, regress_value, label = line_equation,color='red')
    # Incorporate the other graph properties
    plt.grid()
    plt.xlabel(x_axis.name)
    plt.ylabel(y_axis.name)
    plt.title(f"{x_axis.name} vs {y_axis.name} 10/10/2023")
    plt.annotate(line_equation, (max(x_axis),min(y_axis)),fontsize=20,color='red')

    # Show plot
    plt.show()
    
    #Printing background info
    print(f"R value:{rvalue}\nP value:{pvalue}\nStd dev:{stderr}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>=0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City       Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           bilibino  166.4372  68.0546     -8.36        96          99
# 2         abu jibeha   31.2285  11.4562     25.24        58          79
# 4        vilyuchinsk  158.4028  52.9306      7.18        84         100
# 5         lyubinskiy   72.6925  55.1542     13.85        47          92
# 8           hermanus   19.2345 -34.4187     14.67        78          83
#
#          Wind Speed Country        Date
# City_ID
# 0              0.58      RU  1696905256
# 2              2.06      SD  1696905257
# 4              2.28      RU  1696905258
# 5              7.87      RU  1696905259
# 8              9.10      ZA  1696905219

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat']<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                 City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1          grytviken -36.5092 -54.2811      0.32        78          45
# 3        olonkinbyen  -8.7187  70.9221      2.55        89         100
# 6            ushuaia -68.3000 -54.8000     -0.19        93          75
# 7             albany -73.9662  42.6001      9.23        74          38
# 9           qaqortoq -46.0333  60.7167      3.79        62          96
#
#          Wind Speed Country        Date
# City_ID
# 1              4.94      GS  1696905256
# 3              6.64      SJ  1696905258
# 6             12.52      AR  1696905260
# 7              2.03      US  1696905260
# 9              3.03      GL  1696905262

# %%
print(len(northern_hemi_df))
print(len(southern_hemi_df))
# Out:
# 349
# 232

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
Line_Regress(northern_hemi_df['Lat'],northern_hemi_df['Max Temp'])
# Out:
# R value:0.15380066500748088
# P value:0.003975735940567604
# Std dev:0.010294592132706969

# %%
# Linear regression on Southern Hemisphere
Line_Regress(southern_hemi_df['Lat'],southern_hemi_df['Max Temp'])
# Out:
# R value:-0.07243221326880855
# P value:0.2718817540616079
# Std dev:0.01311599204557026

# %% [markdown]
# **Discussion about the linear relationship:
#
# Inital thoughts on the scatter plot seems to be a no correlation between latitude and max temperature but after calculating a linear regression model, we observe a very weak relationship for both northern and southern hemispheres.
#
# With Northern Hemisphere having a very weak postive relation as latitude increase (moving away from the equator) with an r value of 0.15 and Southern Hemisphere having a very weak negative relation as latitude increases (moving closer to the equator) with an r value of -0.07.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
Line_Regress(northern_hemi_df['Lat'],northern_hemi_df['Humidity'])
# Out:
# R value:-0.09967943595629312
# P value:0.06286855306991024
# Std dev:0.023415104509601006

# %%
# Southern Hemisphere
Line_Regress(southern_hemi_df['Lat'],southern_hemi_df['Humidity'])
# Out:
# R value:0.04998710227804883
# P value:0.4486053065321963
# Std dev:0.02857674602878389

# %% [markdown]
# **Discussion about the linear relationship:
#
# From observation of the scatter plot, it would best be described as a no correlation graph but once again calculating the linear regression model we observe a very weak relation between latitude and humidity.
#
# The northern hemisphere has an r value of -0.10 indicated a very weak negative relationship and the southern hemisphere has a r value of 0.05 indicating a very weak positive relationship

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
Line_Regress(northern_hemi_df['Lat'],northern_hemi_df['Cloudiness'])
# Out:
# R value:0.07614464448711962
# P value:0.15576567555987755
# Std dev:0.04277229543865547

# %%
# Southern Hemisphere
Line_Regress(southern_hemi_df['Lat'],southern_hemi_df['Cloudiness'])
# Out:
# R value:0.009415695191497918
# P value:0.8865712493265253
# Std dev:0.062348086907972514

# %% [markdown]
# **Discussion about the linear relationship:
#
# Once again the scatter plot would be first observed as a no correlation between latitude and cloudiness but calculating the linear regression model shows a very weak relationship between them.
#
# The northern hemisphere has an r value of 0.08 indicated a very weak positive relationship and the southern hemisphere has a r value of 0.01 indicating a very weak positive relationship

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
Line_Regress(northern_hemi_df['Lat'],northern_hemi_df['Wind Speed'])
# Out:
# R value:0.1852582451784344
# P value:0.0005039418878310184
# Std dev:0.002487037238711879

# %%
# Southern Hemisphere
Line_Regress(southern_hemi_df['Lat'],southern_hemi_df['Wind Speed'])
# Out:
# R value:-0.05972970025728617
# P value:0.36511023378170737
# Std dev:0.003967712460595251

# %% [markdown]
# **Discussion about the linear relationship:
#
# The graph can be first described as a no correlation between latitude and wind speed for both nothern and southern hemispheres.
#
# Calculating the linear regression model we see an r value of 0.19 for northern hemisphere and a r value of -0.06 for southern hemisphere indicating a very weak postive relation for northern hemisphere and a very weak negative relation for southern hemisphere.
